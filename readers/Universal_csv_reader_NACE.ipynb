# %%
import csv
import numpy as np
import pandas as pd

# %%
def read_csv(file, read_empty_lines=True, formats={}, encoding='utf-8', delimiter=';', quotechar='"', verbose = True):
    with open (file=file, mode='r', encoding=encoding) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=delimiter, quotechar=quotechar)
        header = next(csv_reader)
        for i, column in enumerate(header):
            header[i] = column.strip().replace('\ufeff', '')
        n_columns = len(header)
        n_skipped_rows = 0
        skipped_row = []
        rows = []
        is_individual_format = False
        all_format = 0
        if 'all' in formats.keys():
            if formats['all'] == 'str':
                is_individual_format = False
                all_format = 1
        for i, row in enumerate(csv_reader):
            #print(', '.join(row))
            assert len(row) == n_columns, 'Počet sloupců je divný'
            for j, column in enumerate(header):
                if not is_individual_format and all_format == 0:
                    try:
                        cislo = int(row[j].strip().replace(' ', '').replace(',', '.'))
                    except Exception as e:
                        cislo = row[j].strip()
                        try:
                            cislo = float(row[j].strip().replace(' ', '').replace(',', '.'))
                        except Exception as e:
                            cislo = row[j].strip()
                    if str(cislo) != row[j].strip().replace(' ', '').replace(',', '.'):
                        cislo = row[j].strip()
                    #print(str(cislo), row[j].strip().replace(' ', '').replace(',', '.'))
                else:
                    cislo = row[j].strip()
                if j == 0:    #radky
                    if isinstance(cislo, str) and cislo == '' and not read_empty_lines:
                        skipped_row = ['']
                    else:
                        skipped_row = []
                        rows.append([cislo])
                else:    #cisla
                    if len(skipped_row) == 0:
                        rows[-1].append(cislo)
                    else:
                        if cislo == '':
                            skipped_row.append('')
                            if j == n_columns - 1: #last empty collumn in skipped row
                                n_skipped_rows += 1
                        else:
                            #not an empty row
                            rows.append(skipped_row)
                            skipped_row = []
                            rows[-1].append(cislo)
    assert csv_reader.line_num - 1 - n_skipped_rows == len(rows), 'Počet řádků je divný'
    if verbose:
        print(f'Skipped {n_skipped_rows} empty rows!')
    return rows, header

# %%
#file, delimiter = '_CR_242_PLS_M8_reader_data/CR_242_PLS_M8_old.csv', ';'
file, delimiter = '_NACE_data/nace.csv', '\t'

# %%
data, columns = read_csv(file, read_empty_lines=False, delimiter=delimiter)
# Out:
# Skipped 0 empty rows!

# %%
columns
# Out:
# ['sekce', 'oddil', 'skupina', 'trida', 'nazev']

# %%
len(columns)
# Out:
# 5

# %%
data
# Out:
# [['A', '', '', '', 'SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A\xa0RYBÁŘSTVÍ'],
#  ['A',
#   '01',
#   '',
#   '',
#   'Rostlinná a živočišná výroba, myslivost a související činnosti'],
#  ['A', '01', '01.1', '', 'Pěstování plodin jiných než trvalých'],
#  ['A',
#   '01',
#   '01.1',
#   '01.11',
#   'Pěstování obilovin (kromě rýže), luštěnin a olejnatých semen'],
#  ['A', '01', '01.1', '01.12', 'Pěstování rýže'],
#  ['A', '01', '01.1', '01.13', 'Pěstování zeleniny a melounů, kořenů a hlíz'],
#  ['A', '01', '01.1', '01.14', 'Pěstování cukrové třtiny'],
#  ['A', '01', '01.1', '01.15', 'Pěstování tabáku'],
#  ['A', '01', '01.1', '01.16', 'Pěstování přadných rostlin'],
#  ['A',
#   '01',
#   '01.1',
#   '01.19',
#   'Pěstování ostatních plodin jiných než trvalých'],
#  ['A', '01', '01.2', '', 'Pěstování trvalých plodin'],
#  ['A', '01', '01.2', '01.21', 'Pěstování vinných hroznů'],
#  ['A', '01', '01.2', '01.22', 'Pěstování tropického a subtropického ovoce'],
#  ['A', '01', '01.2', '01.23', 'Pěstování citrusových plodů'],
#  ['A', '01', '01.2', '01.24', 'Pěstování jádrového a peckového ovoce'],
#  ['A',
#   '01',
#   '01.2',
#   '01.25',
#   'Pěstování ostatního stromového a keřového ovoce a\xa0ořechů'],
#  ['A', '01', '01.2', '01.26', 'Pěstování olejnatých plodů'],
#  ['A', '01', '01.2', '01.27', 'Pěstování rostlin pro výrobu nápojů'],
#  ['A',
#   '01',
#   '01.2',
#   '01.28',
#   'Pěstování koření, aromatických, léčivých a\xa0farmaceutických rostlin'],
#  ['A', '01', '01.2', '01.29', 'Pěstování ostatních trvalých plodin'],
#  ['A', '01', '01.3', '', 'Množení rostlin'],
#  ['A', '01', '01.3', '01.30', 'Množení rostlin'],
#  ['A', '01', '01.4', '', 'Živočišná výroba'],
#  ['A', '01', '01.4', '01.41', 'Chov mléčného skotu'],
#  ['A', '01', '01.4', '01.42', 'Chov jiného skotu'],
#  ['A', '01', '01.4', '01.43', 'Chov koní a jiných koňovitých'],
#  ['A', '01', '01.4', '01.44', 'Chov velbloudů a velbloudovitých'],
#  ['A', '01', '01.4', '01.45', 'Chov ovcí a koz'],
#  ['A', '01', '01.4', '01.46', 'Chov prasat'],
#  ['A', '01', '01.4', '01.47', 'Chov drůbeže'],
#  ['A', '01', '01.4', '01.49.1', 'Chov drobných hospodářských zvířat'],
#  ['A', '01', '01.4', '01.49.2', 'Chov kožešinových zvířat'],
#  ['A', '01', '01.4', '01.49.3', 'Chov zvířat pro zájmový chov'],
#  ['A', '01', '01.4', '01.49.9', 'Chov ostatních zvířat j. n.'],
#  ['A', '01', '01.4', '01.49', 'Chov ostatních zvířat'],
#  ['A', '01', '01.5', '', 'Smíšené hospodářství'],
#  ['A', '01', '01.5', '01.50', 'Smíšené hospodářství'],
#  ['A',
#   '01',
#   '01.6',
#   '',
#   'Podpůrné činnosti pro zemědělství a posklizňové činnosti'],
#  ['A', '01', '01.6', '01.61', 'Podpůrné činnosti pro rostlinnou výrobu'],
#  ['A', '01', '01.6', '01.62', 'Podpůrné činnosti pro živočišnou výrobu'],
#  ['A', '01', '01.6', '01.63', 'Posklizňové činnosti'],
#  ['A', '01', '01.6', '01.64', 'Zpracování osiva pro účely množení'],
#  ['A',
#   '01',
#   '01.7',
#   '',
#   'Lov a odchyt divokých zvířat a související činnosti'],
#  ['A',
#   '01',
#   '01.7',
#   '01.70',
#   'Lov a odchyt divokých zvířat a související činnosti'],
#  ['A', '02', '', '', 'Lesnictví a těžba dřeva'],
#  ['A',
#   '02',
#   '02.1',
#   '',
#   'Lesní hospodářství a jiné činnosti v oblasti lesnictví'],
#  ['A',
#   '02',
#   '02.1',
#   '02.10',
#   'Lesní hospodářství a jiné činnosti v oblasti lesnictví'],
#  ['A', '02', '02.2', '', 'Těžba dřeva'],
#  ['A', '02', '02.2', '02.20', 'Těžba dřeva'],
#  ['A',
#   '02',
#   '02.3',
#   '',
#   'Sběr a získávání volně rostoucích plodů a\xa0materiálů, kromě dřeva'],
#  ['A',
#   '02',
#   '02.3',
#   '02.30',
#   'Sběr a získávání volně rostoucích plodů a\xa0materiálů, kromě dřeva'],
#  ['A', '02', '02.4', '', 'Podpůrné činnosti pro lesnictví'],
#  ['A', '02', '02.4', '02.40', 'Podpůrné činnosti pro lesnictví'],
#  ['A', '03', '', '', 'Rybolov a akvakultura'],
#  ['A', '03', '03.1', '', 'Rybolov'],
#  ['A', '03', '03.1', '03.11', 'Mořský rybolov'],
#  ['A', '03', '03.1', '03.12', 'Sladkovodní rybolov'],
#  ['A', '03', '03.2', '', 'Akvakultura'],
#  ['A', '03', '03.2', '03.21', 'Mořská akvakultura'],
#  ['A', '03', '03.2', '03.22', 'Sladkovodní akvakultura'],
#  ['B', '', '', '', 'SEKCE B - TĚŽBA A DOBÝVÁNÍ'],
#  ['B', '05', '', '', 'Těžba a úprava černého a hnědého uhlí'],
#  ['B', '05', '05.1', '', 'Těžba a úprava černého uhlí'],
#  ['B', '05', '05.1', '05.10.1', 'Těžba černého uhlí'],
#  ['B', '05', '05.1', '05.10.2', 'Úprava černého uhlí'],
#  ['B', '05', '05.1', '05.10', 'Těžba a úprava černého uhlí'],
#  ['B', '05', '05.2', '', 'Těžba a úprava hnědého uhlí'],
#  ['B', '05', '05.2', '05.20.1', 'Těžba hnědého uhlí, kromě lignitu'],
#  ['B', '05', '05.2', '05.20.2', 'Úprava hnědého uhlí, kromě lignitu'],
#  ['B', '05', '05.2', '05.20.3', 'Těžba lignitu'],
#  ['B', '05', '05.2', '05.20.4', 'Úprava lignitu'],
#  ['B', '05', '05.2', '05.20', 'Těžba a úprava hnědého uhlí'],
#  ['B', '06', '', '', 'Těžba ropy a zemního plynu'],
#  ['B', '06', '06.1', '', 'Těžba ropy'],
#  ['B', '06', '06.1', '06.10', 'Těžba ropy'],
#  ['B', '06', '06.2', '', 'Těžba zemního plynu'],
#  ['B', '06', '06.2', '06.20', 'Těžba zemního plynu'],
#  ['B', '07', '', '', 'Těžba a úprava rud'],
#  ['B', '07', '07.1', '', 'Těžba a úprava železných rud'],
#  ['B', '07', '07.1', '07.10.1', 'Těžba železných rud'],
#  ['B', '07', '07.1', '07.10.2', 'Úprava železných rud'],
#  ['B', '07', '07.1', '07.10', 'Těžba a úprava železných rud'],
#  ['B', '07', '07.2', '', 'Těžba a úprava neželezných rud'],
#  ['B', '07', '07.2', '07.21.1', 'Těžba uranových a thoriových rud'],
#  ['B', '07', '07.2', '07.21.2', 'Úprava uranových a thoriových rud'],
#  ['B', '07', '07.2', '07.21', 'Těžba a úprava uranových a thoriových rud'],
#  ['B', '07', '07.2', '07.29.1', 'Těžba ostatních neželezných rud'],
#  ['B', '07', '07.2', '07.29.2', 'Úprava ostatních neželezných rud'],
#  ['B', '07', '07.2', '07.29', 'Těžba a úprava ostatních neželezných rud'],
#  ['B', '08', '', '', 'Ostatní těžba a dobývání'],
#  ['B', '08', '08.1', '', 'Dobývání kamene, písků a jílů'],
#  ['B',
#   '08',
#   '08.1',
#   '08.11',
#   'Dobývání kamene pro výtvarné nebo stavební účely, vápence, sádrovce, křídy a břidlice'],
#  ['B',
#   '08',
#   '08.1',
#   '08.12',
#   'Provoz pískoven a štěrkopískoven; těžba jílů a kaolinu'],
#  ['B', '08', '08.9', '', 'Těžba a dobývání j. n.'],
#  ['B',
#   '08',
#   '08.9',
#   '08.91',
#   'Těžba chemických minerálů a minerálů pro výrobu hnojiv'],
#  ['B', '08', '08.9', '08.92', 'Těžba rašeliny'],
#  ['B', '08', '08.9', '08.93', 'Těžba soli'],
#  ['B', '08', '08.9', '08.99', 'Ostatní těžba a dobývání j. n.'],
#  ['B', '09', '', '', 'Podpůrné činnosti při těžbě'],
#  ['B', '09', '09.1', '', 'Podpůrné činnosti při těžbě ropy a zemního plynu'],
#  ['B',
#   '09',
#   '09.1',
#   '09.10',
#   'Podpůrné činnosti při těžbě ropy a zemního plynu'],
#  ['B', '09', '09.9', '', 'Podpůrné činnosti při ostatní těžbě a dobývání'],
#  ['B',
#   '09',
#   '09.9',
#   '09.90',
#   'Podpůrné činnosti při ostatní těžbě a dobývání'],
#  ['C', '', '', '', 'SEKCE C - ZPRACOVATELSKÝ PRŮMYSL'],
#  ['C', 10, '', '', 'Výroba potravinářských výrobků'],
#  ['C',
#   10,
#   10.1,
#   '',
#   'Zpracování a konzervování masa a výroba masných výrobků'],
#  ['C', 10, 10.1, 10.11, 'Zpracování a konzervování masa, kromě drůbežího'],
#  ['C', 10, 10.1, 10.12, 'Zpracování a konzervování drůbežího masa'],
#  ['C',
#   10,
#   10.1,
#   10.13,
#   'Výroba masných výrobků a výrobků z\xa0drůbežího masa'],
#  ['C', 10, 10.2, '', 'Zpracování a konzervování ryb, korýšů a měkkýšů'],
#  ['C', 10, 10.2, '10.20', 'Zpracování a konzervování ryb, korýšů a měkkýšů'],
#  ['C', 10, 10.3, '', 'Zpracování a konzervování ovoce a zeleniny'],
#  ['C', 10, 10.3, 10.31, 'Zpracování a konzervování brambor'],
#  ['C', 10, 10.3, 10.32, 'Výroba ovocných a zeleninových šťáv'],
#  ['C', 10, 10.3, 10.39, 'Ostatní zpracování a konzervování ovoce a zeleniny'],
#  ['C', 10, 10.4, '', 'Výroba rostlinných a živočišných olejů a tuků'],
#  ['C', 10, 10.4, 10.41, 'Výroba olejů a tuků'],
#  ['C', 10, 10.4, 10.42, 'Výroba margarínu a podobných jedlých tuků'],
#  ['C', 10, 10.5, '', 'Výroba mléčných výrobků'],
#  ['C', 10, 10.5, 10.51, 'Zpracování mléka, výroba mléčných výrobků a sýrů'],
#  ['C', 10, 10.5, 10.52, 'Výroba zmrzliny'],
#  ['C', 10, 10.6, '', 'Výroba mlýnských a škrobárenských výrobků'],
#  ['C', 10, 10.6, 10.61, 'Výroba mlýnských výrobků'],
#  ['C', 10, 10.6, 10.62, 'Výroba škrobárenských výrobků'],
#  ['C',
#   10,
#   10.7,
#   '',
#   'Výroba pekařských, cukrářských a jiných moučných výrobků'],
#  ['C',
#   10,
#   10.7,
#   10.71,
#   'Výroba pekařských a cukrářských výrobků, kromě trvanlivých'],
#  ['C',
#   10,
#   10.7,
#   10.72,
#   'Výroba sucharů a sušenek; výroba trvanlivých cukrářských výrobků'],
#  ['C',
#   10,
#   10.7,
#   10.73,
#   'Výroba makaronů, nudlí, kuskusu a podobných moučných výrobků'],
#  ['C', 10, 10.8, '', 'Výroba ostatních potravinářských výrobků'],
#  ['C', 10, 10.8, 10.81, 'Výroba cukru'],
#  ['C', 10, 10.8, 10.82, 'Výroba kakaa, čokolády a cukrovinek'],
#  ['C', 10, 10.8, 10.83, 'Zpracování čaje a kávy'],
#  ['C', 10, 10.8, 10.84, 'Výroba koření a aromatických výtažků'],
#  ['C', 10, 10.8, 10.85, 'Výroba hotových pokrmů'],
#  ['C',
#   10,
#   10.8,
#   10.86,
#   'Výroba homogenizovaných potravinářských přípravků a dietních potravin'],
#  ['C', 10, 10.8, 10.89, 'Výroba ostatních potravinářských výrobků j. n.'],
#  ['C', 10, 10.9, '', 'Výroba průmyslových krmiv'],
#  ['C', 10, 10.9, 10.91, 'Výroba průmyslových krmiv pro hospodářská zvířata'],
#  ['C',
#   10,
#   10.9,
#   10.92,
#   'Výroba průmyslových krmiv pro zvířata v\xa0zájmovém chovu'],
#  ['C', 11, '', '', 'Výroba nápojů'],
#  ['C', 11, 11.0, '', 'Výroba nápojů'],
#  ['C', 11, 11.0, 11.01, 'Destilace, rektifikace a míchání lihovin'],
#  ['C', 11, 11.0, 11.02, 'Výroba vína z\xa0vinných hroznů'],
#  ['C', 11, 11.0, 11.03, 'Výroba jablečného vína a jiných ovocných vín'],
#  ['C', 11, 11.0, 11.04, 'Výroba ostatních nedestilovaných kvašených nápojů'],
#  ['C', 11, 11.0, 11.05, 'Výroba piva'],
#  ['C', 11, 11.0, 11.06, 'Výroba sladu'],
#  ['C',
#   11,
#   11.0,
#   11.07,
#   'Výroba nealkoholických nápojů; stáčení minerálních a\xa0ostatních vod do\xa0lahví'],
#  ['C', 12, '', '', 'Výroba tabákových výrobků'],
#  ['C', 12, 12.0, '', 'Výroba tabákových výrobků'],
#  ['C', 12, 12.0, '12.00', 'Výroba tabákových výrobků'],
#  ['C', 13, '', '', 'Výroba textilií'],
#  ['C', 13, 13.1, '', 'Úprava a spřádání textilních vláken a příze'],
#  ['C', 13, 13.1, '13.10', 'Úprava a spřádání textilních vláken a příze'],
#  ['C', 13, 13.2, '', 'Tkaní textilií'],
#  ['C', 13, 13.2, '13.20', 'Tkaní textilií'],
#  ['C', 13, 13.3, '', 'Konečná úprava textilií'],
#  ['C', 13, 13.3, '13.30', 'Konečná úprava textilií'],
#  ['C', 13, 13.9, '', 'Výroba ostatních textilií'],
#  ['C', 13, 13.9, 13.91, 'Výroba pletených a háčkovaných materiálů'],
#  ['C', 13, 13.9, 13.92, 'Výroba konfekčních textilních výrobků, kromě oděvů'],
#  ['C', 13, 13.9, 13.93, 'Výroba koberců a kobercových předložek'],
#  ['C', 13, 13.9, 13.94, 'Výroba lan, provazů a síťovaných výrobků'],
#  ['C',
#   13,
#   13.9,
#   13.95,
#   'Výroba netkaných textilií a výrobků z\xa0nich, kromě oděvů'],
#  ['C',
#   13,
#   13.9,
#   13.96,
#   'Výroba ostatních technických a průmyslových textilií'],
#  ['C', 13, 13.9, 13.99, 'Výroba ostatních textilií j. n.'],
#  ['C', 14, '', '', 'Výroba oděvů'],
#  ['C', 14, 14.1, '', 'Výroba oděvů, kromě kožešinových výrobků'],
#  ['C', 14, 14.1, 14.11, 'Výroba kožených oděvů'],
#  ['C', 14, 14.1, 14.12, 'Výroba pracovních oděvů'],
#  ['C', 14, 14.1, 14.13, 'Výroba ostatních svrchních oděvů'],
#  ['C', 14, 14.1, 14.14, 'Výroba osobního prádla'],
#  ['C', 14, 14.1, 14.19, 'Výroba ostatních oděvů a oděvních doplňků'],
#  ['C', 14, 14.2, '', 'Výroba kožešinových výrobků'],
#  ['C', 14, 14.2, '14.20', 'Výroba kožešinových výrobků'],
#  ['C', 14, 14.3, '', 'Výroba pletených a háčkovaných oděvů'],
#  ['C', 14, 14.3, 14.31, 'Výroba pletených a háčkovaných punčochových výrobků'],
#  ['C', 14, 14.3, 14.39, 'Výroba ostatních pletených a háčkovaných oděvů'],
#  ['C', 15, '', '', 'Výroba usní a souvisejících výrobků'],
#  ['C',
#   15,
#   15.1,
#   '',
#   'Činění a úprava usní (vyčiněných kůží); zpracování a\xa0barvení kožešin; výroba brašnářských,\xa0sedlářských a podobných výrobků'],
#  ['C',
#   15,
#   15.1,
#   15.11,
#   'Činění a úprava usní (vyčiněných kůží); zpracování a\xa0barvení kožešin'],
#  ['C',
#   15,
#   15.1,
#   15.12,
#   'Výroba brašnářských, sedlářských a podobných výrobků'],
#  ['C', 15, 15.2, '', 'Výroba obuvi'],
#  ['C', 15, 15.2, '15.20.1', 'Výroba obuvi s\xa0usňovým svrškem'],
#  ['C', 15, 15.2, '15.20.9', 'Výroba obuvi z\xa0ostatních materiálů'],
#  ['C', 15, 15.2, '15.20', 'Výroba obuvi'],
#  ['C',
#   16,
#   '',
#   '',
#   'Zpracování dřeva, výroba dřevěných, korkových, proutěných a slaměných výrobků, kromě nábytku'],
#  ['C', 16, 16.1, '', 'Výroba pilařská a impregnace dřeva'],
#  ['C', 16, 16.1, '16.10', 'Výroba pilařská a impregnace dřeva'],
#  ['C',
#   16,
#   16.2,
#   '',
#   'Výroba dřevěných, korkových, proutěných a\xa0slaměných výrobků, kromě nábytku'],
#  ['C', 16, 16.2, 16.21, 'Výroba dýh a desek na bázi dřeva'],
#  ['C', 16, 16.2, 16.22, 'Výroba sestavených parketových podlah'],
#  ['C',
#   16,
#   16.2,
#   16.23,
#   'Výroba ostatních výrobků stavebního truhlářství a\xa0tesařství'],
#  ['C', 16, 16.2, 16.24, 'Výroba dřevěných obalů'],
#  ['C',
#   16,
#   16.2,
#   16.29,
#   'Výroba ostatních dřevěných, korkových, proutěných a slaměných výrobků, kromě nábytku'],
#  ['C', 17, '', '', 'Výroba papíru a výrobků z papíru'],
#  ['C', 17, 17.1, '', 'Výroba buničiny, papíru a lepenky'],
#  ['C', 17, 17.1, '17.11.1', 'Výroba chemických buničin'],
#  ['C', 17, 17.1, '17.11.2', 'Výroba mechanických vláknin'],
#  ['C', 17, 17.1, '17.11.3', 'Výroba ostatních papírenských vláknin'],
#  ['C', 17, 17.1, 17.11, 'Výroba buničiny'],
#  ['C', 17, 17.1, 17.12, 'Výroba papíru a lepenky'],
#  ['C', 17, 17.2, '', 'Výroba výrobků z papíru a lepenky'],
#  ['C',
#   17,
#   17.2,
#   17.21,
#   'Výroba vlnitého papíru a lepenky, papírových a\xa0lepenkových obalů'],
#  ['C',
#   17,
#   17.2,
#   17.22,
#   'Výroba domácích potřeb, hygienických a toaletních výrobků z papíru'],
#  ['C', 17, 17.2, 17.23, 'Výroba kancelářských potřeb z papíru'],
#  ['C', 17, 17.2, 17.24, 'Výroba tapet'],
#  ['C', 17, 17.2, 17.29, 'Výroba ostatních výrobků z papíru a lepenky'],
#  ['C', 18, '', '', 'Tisk a rozmnožování nahraných nosičů'],
#  ['C', 18, 18.1, '', 'Tisk a činnosti související s tiskem'],
#  ['C', 18, 18.1, 18.11, 'Tisk novin'],
#  ['C', 18, 18.1, 18.12, 'Tisk ostatní, kromě novin'],
#  ['C', 18, 18.1, 18.13, 'Příprava tisku a digitálních dat'],
#  ['C', 18, 18.1, 18.14, 'Vázání a související činnosti'],
#  ['C', 18, 18.2, '', 'Rozmnožování nahraných nosičů'],
#  ['C', 18, 18.2, '18.20', 'Rozmnožování nahraných nosičů'],
#  ['C', 19, '', '', 'Výroba koksu a rafinovaných ropných produktů'],
#  ['C', 19, 19.1, '', 'Výroba koksárenských produktů'],
#  ['C', 19, 19.1, '19.10', 'Výroba koksárenských produktů'],
#  ['C', 19, 19.2, '', 'Výroba rafinovaných ropných produktů'],
#  ['C', 19, 19.2, '19.20', 'Výroba rafinovaných ropných produktů'],
#  ['C', 20, '', '', 'Výroba chemických látek a chemických přípravků'],
#  ['C',
#   20,
#   20.1,
#   '',
#   'Výroba základních chemických látek, hnojiv a\xa0dusíkatých sloučenin, plastů a syntetického kaučuku v primárních formách'],
#  ['C', 20, 20.1, 20.11, 'Výroba technických plynů'],
#  ['C', 20, 20.1, 20.12, 'Výroba barviv a pigmentů'],
#  ['C',
#   20,
#   20.1,
#   20.13,
#   'Výroba jiných základních anorganických chemických látek'],
#  ['C',
#   20,
#   20.1,
#   '20.14.1',
#   'Výroba bioetanolu (biolihu) pro pohon motorů a pro výrobu směsí a\xa0komponent paliv pro pohon motorů'],
#  ['C',
#   20,
#   20.1,
#   '20.14.9',
#   'Výroba ostatních základních organických chemických látek'],
#  ['C',
#   20,
#   20.1,
#   20.14,
#   'Výroba jiných základních organických chemických látek'],
#  ['C', 20, 20.1, 20.15, 'Výroba hnojiv a dusíkatých sloučenin'],
#  ['C', 20, 20.1, 20.16, 'Výroba plastů v primárních formách'],
#  ['C', 20, 20.1, 20.17, 'Výroba syntetického kaučuku v primárních formách'],
#  ['C', 20, 20.2, '', 'Výroba pesticidů a jiných agrochemických přípravků'],
#  ['C',
#   20,
#   20.2,
#   '20.20',
#   'Výroba pesticidů a jiných agrochemických přípravků'],
#  ['C',
#   20,
#   20.3,
#   '',
#   'Výroba nátěrových barev, laků a jiných nátěrových materiálů, tiskařských barev a tmelů'],
#  ['C',
#   20,
#   20.3,
#   '20.30',
#   'Výroba nátěrových barev, laků a jiných nátěrových materiálů, tiskařských barev a tmelů'],
#  ['C',
#   20,
#   20.4,
#   '',
#   'Výroba mýdel a detergentů, čisticích a lešticích prostředků, parfémů a\xa0toaletních přípravků'],
#  ['C',
#   20,
#   20.4,
#   20.41,
#   'Výroba mýdel a detergentů, čisticích a lešticích prostředků'],
#  ['C', 20, 20.4, 20.42, 'Výroba parfémů a toaletních přípravků'],
#  ['C', 20, 20.5, '', 'Výroba ostatních chemických výrobků'],
#  ['C', 20, 20.5, 20.51, 'Výroba výbušnin'],
#  ['C', 20, 20.5, 20.52, 'Výroba klihů'],
#  ['C', 20, 20.5, 20.53, 'Výroba vonných silic'],
#  ['C',
#   20,
#   20.5,
#   '20.59.1',
#   'Výroba metylesterů a etylesterů mastných kyselin pro pohon motorů a\xa0pro\xa0výrobu směsí paliv pro pohon motorů'],
#  ['C', 20, 20.5, '20.59.9', 'Výroba jiných chemických výrobků j. n.'],
#  ['C', 20, 20.5, 20.59, 'Výroba ostatních chemických výrobků j. n.'],
#  ['C', 20, 20.6, '', 'Výroba chemických vláken'],
#  ['C', 20, 20.6, '20.60', 'Výroba chemických vláken'],
#  ['C',
#   21,
#   '',
#   '',
#   'Výroba základních farmaceutických výrobků a\xa0farmaceutických přípravků'],
#  ['C', 21, 21.1, '', 'Výroba základních farmaceutických výrobků'],
#  ['C', 21, 21.1, '21.10', 'Výroba základních farmaceutických výrobků'],
#  ['C', 21, 21.2, '', 'Výroba farmaceutických přípravků'],
#  ['C', 21, 21.2, '21.20', 'Výroba farmaceutických přípravků'],
#  ['C', 22, '', '', 'Výroba pryžových a plastových výrobků'],
#  ['C', 22, 22.1, '', 'Výroba pryžových výrobků'],
#  ['C',
#   22,
#   22.1,
#   22.11,
#   'Výroba pryžových plášťů a duší; protektorování pneumatik'],
#  ['C', 22, 22.1, 22.19, 'Výroba ostatních pryžových výrobků'],
#  ['C', 22, 22.2, '', 'Výroba plastových výrobků'],
#  ['C',
#   22,
#   22.2,
#   22.21,
#   'Výroba plastových desek, fólií, hadic, trubek a profilů'],
#  ['C', 22, 22.2, 22.22, 'Výroba plastových obalů'],
#  ['C', 22, 22.2, 22.23, 'Výroba plastových výrobků pro stavebnictví'],
#  ['C', 22, 22.2, 22.29, 'Výroba ostatních plastových výrobků'],
#  ['C', 23, '', '', 'Výroba ostatních nekovových minerálních výrobků'],
#  ['C', 23, 23.1, '', 'Výroba skla a skleněných výrobků'],
#  ['C', 23, 23.1, 23.11, 'Výroba plochého skla'],
#  ['C', 23, 23.1, 23.12, 'Tvarování a zpracování plochého skla'],
#  ['C', 23, 23.1, 23.13, 'Výroba dutého skla'],
#  ['C', 23, 23.1, 23.14, 'Výroba skleněných vláken'],
#  ['C', 23, 23.1, 23.19, 'Výroba a zpracování ostatního skla vč. technického'],
#  ['C', 23, 23.2, '', 'Výroba žáruvzdorných výrobků'],
#  ['C', 23, 23.2, '23.20', 'Výroba žáruvzdorných výrobků'],
#  ['C', 23, 23.3, '', 'Výroba stavebních výrobků z jílovitých materiálů'],
#  ['C', 23, 23.3, 23.31, 'Výroba keramických obkládaček a dlaždic'],
#  ['C',
#   23,
#   23.3,
#   23.32,
#   'Výroba pálených zdicích materiálů, tašek, dlaždic a\xa0podobných výrobků'],
#  ['C', 23, 23.4, '', 'Výroba ostatních porcelánových a keramických výrobků'],
#  ['C',
#   23,
#   23.4,
#   23.41,
#   'Výroba keramických a porcelánových výrobků převážně pro domácnost a\xa0ozdobných předmětů'],
#  ['C', 23, 23.4, 23.42, 'Výroba keramických sanitárních výrobků'],
#  ['C',
#   23,
#   23.4,
#   23.43,
#   'Výroba keramických izolátorů a izolačního příslušenství'],
#  ['C', 23, 23.4, 23.44, 'Výroba ostatních technických keramických výrobků'],
#  ['C', 23, 23.4, 23.49, 'Výroba ostatních keramických výrobků'],
#  ['C', 23, 23.5, '', 'Výroba cementu, vápna a sádry'],
#  ['C', 23, 23.5, 23.51, 'Výroba cementu'],
#  ['C', 23, 23.5, 23.52, 'Výroba vápna a sádry'],
#  ['C', 23, 23.6, '', 'Výroba betonových, cementových a sádrových výrobků'],
#  ['C', 23, 23.6, 23.61, 'Výroba betonových výrobků pro stavební účely'],
#  ['C', 23, 23.6, 23.62, 'Výroba sádrových výrobků pro stavební účely'],
#  ['C', 23, 23.6, 23.63, 'Výroba betonu připraveného k lití'],
#  ['C', 23, 23.6, 23.64, 'Výroba malt'],
#  ['C', 23, 23.6, 23.65, 'Výroba vláknitých cementů'],
#  ['C',
#   23,
#   23.6,
#   23.69,
#   'Výroba ostatních betonových, cementových a\xa0sádrových výrobků'],
#  ['C', 23, 23.7, '', 'Řezání, tvarování a konečná úprava kamenů'],
#  ['C', 23, 23.7, '23.70', 'Řezání, tvarování a konečná úprava kamenů'],
#  ['C',
#   23,
#   23.9,
#   '',
#   'Výroba brusiv a ostatních nekovových minerálních výrobků j. n.'],
#  ['C', 23, 23.9, 23.91, 'Výroba brusiv'],
#  ['C',
#   23,
#   23.9,
#   23.99,
#   'Výroba ostatních nekovových minerálních výrobků j.\xa0n.'],
#  ['C',
#   24,
#   '',
#   '',
#   'Výroba základních kovů, hutní zpracování kovů; slévárenství'],
#  ['C',
#   24,
#   24.1,
#   '',
#   'Výroba surového železa, oceli a feroslitin, plochých výrobků (kromě pásky za studena), tváření výrobků za tepla'],
#  ['C', 24, 24.1, '24.10.1', 'Výroba surového železa, oceli a feroslitin'],
#  ['C',
#   24,
#   24.1,
#   '24.10.2',
#   'Výroba plochých výrobků (kromě pásky za studena)'],
#  ['C', 24, 24.1, '24.10.3', 'Tváření výrobků za tepla'],
#  ['C',
#   24,
#   24.1,
#   '24.10',
#   'Výroba surového železa, oceli a feroslitin, plochých výrobků (kromě pásky za studena), tváření výrobků za tepla'],
#  ['C',
#   24,
#   24.2,
#   '',
#   'Výroba ocelových trub, trubek, dutých profilů a\xa0souvisejících potrubních tvarovek'],
#  ['C',
#   24,
#   24.2,
#   '24.20',
#   'Výroba ocelových trub, trubek, dutých profilů a\xa0souvisejících potrubních tvarovek'],
#  ['C',
#   24,
#   24.3,
#   '',
#   'Výroba ostatních výrobků získaných jednostupňovým zpracováním oceli'],
#  ['C', 24, 24.3, 24.31, 'Tažení tyčí za studena'],
#  ['C', 24, 24.3, 24.32, 'Válcování ocelových úzkých pásů za studena'],
#  ['C', 24, 24.3, 24.33, 'Tváření ocelových profilů za studena'],
#  ['C', 24, 24.3, 24.34, 'Tažení ocelového drátu za studena'],
#  ['C', 24, 24.4, '', 'Výroba a hutní zpracování drahých a neželezných kovů'],
#  ['C', 24, 24.4, 24.41, 'Výroba a hutní zpracování drahých kovů'],
#  ['C', 24, 24.4, 24.42, 'Výroba a hutní zpracování hliníku'],
#  ['C', 24, 24.4, 24.43, 'Výroba a hutní zpracování olova, zinku a cínu'],
#  ['C', 24, 24.4, 24.44, 'Výroba a hutní zpracování mědi'],
#  ['C',
#   24,
#   24.4,
#   24.45,
#   'Výroba a hutní zpracování ostatních neželezných kovů'],
#  ['C', 24, 24.4, 24.46, 'Zpracování jaderného paliva'],
#  ['C', 24, 24.5, '', 'Slévárenství'],
#  ['C', 24, 24.5, '24.51.1', 'Výroba odlitků z litiny s lupínkovým grafitem'],
#  ['C', 24, 24.5, '24.51.2', 'Výroba odlitků z litiny s kuličkovým grafitem'],
#  ['C', 24, 24.5, '24.51.9', 'Výroba ostatních odlitků z litiny'],
#  ['C', 24, 24.5, 24.51, 'Výroba odlitků z litiny'],
#  ['C', 24, 24.5, '24.52.1', 'Výroba odlitků z uhlíkatých ocelí'],
#  ['C', 24, 24.5, '24.52.2', 'Výroba odlitků z legovaných ocelí'],
#  ['C', 24, 24.5, 24.52, 'Výroba odlitků z oceli'],
#  ['C', 24, 24.5, 24.53, 'Výroba odlitků z lehkých neželezných kovů'],
#  ['C', 24, 24.5, 24.54, 'Výroba odlitků z ostatních neželezných kovů'],
#  ['C',
#   25,
#   '',
#   '',
#   'Výroba kovových konstrukcí a kovodělných výrobků, kromě strojů a\xa0zařízení'],
#  ['C', 25, 25.1, '', 'Výroba konstrukčních kovových výrobků'],
#  ['C', 25, 25.1, 25.11, 'Výroba kovových konstrukcí a jejich dílů'],
#  ['C', 25, 25.1, 25.12, 'Výroba kovových dveří a oken'],
#  ['C',
#   25,
#   25.2,
#   '',
#   'Výroba radiátorů a kotlů k ústřednímu topení, kovových nádrží a zásobníků'],
#  ['C', 25, 25.2, 25.21, 'Výroba radiátorů a kotlů k ústřednímu topení'],
#  ['C', 25, 25.2, 25.29, 'Výroba kovových nádrží a zásobníků'],
#  ['C', 25, 25.3, '', 'Výroba parních kotlů, kromě kotlů pro ústřední topení'],
#  ['C',
#   25,
#   25.3,
#   '25.30',
#   'Výroba parních kotlů, kromě kotlů pro ústřední topení'],
#  ['C', 25, 25.4, '', 'Výroba zbraní a střeliva'],
#  ['C', 25, 25.4, '25.40', 'Výroba zbraní a střeliva'],
#  ['C',
#   25,
#   25.5,
#   '',
#   'Kování, lisování, ražení, válcování a protlačování kovů; prášková metalurgie'],
#  ['C',
#   25,
#   25.5,
#   '25.50',
#   'Kování, lisování, ražení, válcování a protlačování kovů; prášková metalurgie'],
#  ['C', 25, 25.6, '', 'Povrchová úprava a zušlechťování kovů; obrábění'],
#  ['C', 25, 25.6, 25.61, 'Povrchová úprava a zušlechťování kovů'],
#  ['C', 25, 25.6, 25.62, 'Obrábění'],
#  ['C',
#   25,
#   25.7,
#   '',
#   'Výroba nožířských výrobků, nástrojů a\xa0železářských výrobků'],
#  ['C', 25, 25.7, 25.71, 'Výroba nožířských výrobků'],
#  ['C', 25, 25.7, 25.72, 'Výroba zámků a kování'],
#  ['C', 25, 25.7, 25.73, 'Výroba nástrojů a nářadí'],
#  ['C', 25, 25.9, '', 'Výroba ostatních kovodělných výrobků'],
#  ['C', 25, 25.9, 25.91, 'Výroba ocelových sudů a podobných nádob'],
#  ['C', 25, 25.9, 25.92, 'Výroba drobných kovových obalů'],
#  ['C', 25, 25.9, 25.93, 'Výroba drátěných výrobků, řetězů a pružin'],
#  ['C',
#   25,
#   25.9,
#   25.94,
#   'Výroba spojovacích materiálů a spojovacích výrobků se\xa0závity'],
#  ['C', 25, 25.9, 25.99, 'Výroba ostatních kovodělných výrobků j. n.'],
#  ['C',
#   26,
#   '',
#   '',
#   'Výroba počítačů, elektronických a optických přístrojů a zařízení'],
#  ['C', 26, 26.1, '', 'Výroba elektronických součástek a desek'],
#  ['C', 26, 26.1, 26.11, 'Výroba elektronických součástek'],
#  ['C', 26, 26.1, 26.12, 'Výroba osazených elektronických desek'],
#  ['C', 26, 26.2, '', 'Výroba počítačů a periferních zařízení'],
#  ['C', 26, 26.2, '26.20', 'Výroba počítačů a periferních zařízení'],
#  ['C', 26, 26.3, '', 'Výroba komunikačních zařízení'],
#  ['C', 26, 26.3, '26.30', 'Výroba komunikačních zařízení'],
#  ['C', 26, 26.4, '', 'Výroba spotřební elektroniky'],
#  ['C', 26, 26.4, '26.40', 'Výroba spotřební elektroniky'],
#  ['C',
#   26,
#   26.5,
#   '',
#   'Výroba měřicích, zkušebních a navigačních přístrojů; výroba časoměrných přístrojů'],
#  ['C', 26, 26.5, 26.51, 'Výroba měřicích, zkušebních a navigačních přístrojů'],
#  ['C', 26, 26.5, 26.52, 'Výroba časoměrných přístrojů'],
#  ['C',
#   26,
#   26.6,
#   '',
#   'Výroba ozařovacích, elektroléčebných a\xa0elektroterapeutických přístrojů'],
#  ['C',
#   26,
#   26.6,
#   '26.60',
#   'Výroba ozařovacích, elektroléčebných a\xa0elektroterapeutických přístrojů'],
#  ['C', 26, 26.7, '', 'Výroba optických a fotografických přístrojů a zařízení'],
#  ['C',
#   26,
#   26.7,
#   '26.70',
#   'Výroba optických a fotografických přístrojů a zařízení'],
#  ['C', 26, 26.8, '', 'Výroba magnetických a optických médií'],
#  ['C', 26, 26.8, '26.80', 'Výroba magnetických a optických médií'],
#  ['C', 27, '', '', 'Výroba elektrických zařízení'],
#  ['C',
#   27,
#   27.1,
#   '',
#   'Výroba elektrických motorů, generátorů, transformátorů a\xa0elektrických rozvodných a kontrolních zařízení'],
#  ['C',
#   27,
#   27.1,
#   27.11,
#   'Výroba elektrických motorů, generátorů a\xa0transformátorů'],
#  ['C',
#   27,
#   27.1,
#   27.12,
#   'Výroba elektrických rozvodných a kontrolních zařízení'],
#  ['C', 27, 27.2, '', 'Výroba baterií a akumulátorů'],
#  ['C', 27, 27.2, '27.20', 'Výroba baterií a akumulátorů'],
#  ['C',
#   27,
#   27.3,
#   '',
#   'Výroba optických a elektrických kabelů, elektrických vodičů a elektroinstalačních zařízení'],
#  ['C', 27, 27.3, 27.31, 'Výroba optických kabelů'],
#  ['C', 27, 27.3, 27.32, 'Výroba elektrických vodičů a kabelů j. n.'],
#  ['C', 27, 27.3, 27.33, 'Výroba elektroinstalačních zařízení'],
#  ['C', 27, 27.4, '', 'Výroba elektrických osvětlovacích zařízení'],
#  ['C', 27, 27.4, '27.40', 'Výroba elektrických osvětlovacích zařízení'],
#  ['C', 27, 27.5, '', 'Výroba spotřebičů převážně pro domácnost'],
#  ['C',
#   27,
#   27.5,
#   27.51,
#   'Výroba elektrických spotřebičů převážně pro\xa0domácnost'],
#  ['C',
#   27,
#   27.5,
#   27.52,
#   'Výroba neelektrických spotřebičů převážně pro\xa0domácnost'],
#  ['C', 27, 27.9, '', 'Výroba ostatních elektrických zařízení'],
#  ['C', 27, 27.9, '27.90', 'Výroba ostatních elektrických zařízení'],
#  ['C', 28, '', '', 'Výroba strojů a zařízení j. n.'],
#  ['C', 28, 28.1, '', 'Výroba strojů a zařízení pro všeobecné účely'],
#  ['C',
#   28,
#   28.1,
#   28.11,
#   'Výroba motorů a turbín, kromě motorů pro letadla, automobily a\xa0motocykly'],
#  ['C', 28, 28.1, 28.12, 'Výroba hydraulických a pneumatických zařízení'],
#  ['C', 28, 28.1, 28.13, 'Výroba ostatních čerpadel a kompresorů'],
#  ['C', 28, 28.1, 28.14, 'Výroba ostatních potrubních armatur'],
#  ['C',
#   28,
#   28.1,
#   28.15,
#   'Výroba ložisek, ozubených kol, převodů a hnacích prvků'],
#  ['C', 28, 28.2, '', 'Výroba ostatních strojů a zařízení pro všeobecné účely'],
#  ['C', 28, 28.2, 28.21, 'Výroba pecí a hořáků pro topeniště'],
#  ['C', 28, 28.2, 28.22, 'Výroba zdvihacích a manipulačních zařízení'],
#  ['C',
#   28,
#   28.2,
#   28.23,
#   'Výroba kancelářských strojů a zařízení, kromě počítačů a periferních zařízení'],
#  ['C', 28, 28.2, 28.24, 'Výroba ručních mechanizovaných nástrojů'],
#  ['C',
#   28,
#   28.2,
#   28.25,
#   'Výroba průmyslových chladicích a klimatizačních zařízení'],
#  ['C',
#   28,
#   28.2,
#   28.29,
#   'Výroba ostatních strojů a zařízení pro všeobecné účely j. n.'],
#  ['C', 28, 28.3, '', 'Výroba zemědělských a lesnických strojů'],
#  ['C', 28, 28.3, '28.30', 'Výroba zemědělských a lesnických strojů'],
#  ['C', 28, 28.4, '', 'Výroba kovoobráběcích a ostatních obráběcích strojů'],
#  ['C', 28, 28.4, 28.41, 'Výroba kovoobráběcích strojů'],
#  ['C', 28, 28.4, 28.49, 'Výroba ostatních obráběcích strojů'],
#  ['C', 28, 28.9, '', 'Výroba ostatních strojů pro speciální účely'],
#  ['C', 28, 28.9, 28.91, 'Výroba strojů pro metalurgii'],
#  ['C', 28, 28.9, 28.92, 'Výroba strojů pro těžbu, dobývání a stavebnictví'],
#  ['C',
#   28,
#   28.9,
#   28.93,
#   'Výroba strojů na výrobu potravin, nápojů a\xa0zpracování tabáku'],
#  ['C',
#   28,
#   28.9,
#   28.94,
#   'Výroba strojů na výrobu textilu, oděvních výrobků a\xa0výrobků z usní'],
#  ['C',
#   28,
#   28.9,
#   28.95,
#   'Výroba strojů a přístrojů na výrobu papíru a lepenky'],
#  ['C', 28, 28.9, 28.96, 'Výroba strojů na výrobu plastů a pryže'],
#  ['C', 28, 28.9, 28.99, 'Výroba ostatních strojů pro speciální účely j. n.'],
#  ['C',
#   29,
#   '',
#   '',
#   'Výroba motorových vozidel (kromě motocyklů), přívěsů a návěsů'],
#  ['C', 29, 29.1, '', 'Výroba motorových vozidel a jejich motorů'],
#  ['C', 29, 29.1, '29.10', 'Výroba motorových vozidel a jejich motorů'],
#  ['C',
#   29,
#   29.2,
#   '',
#   'Výroba karoserií motorových vozidel; výroba přívěsů a návěsů'],
#  ['C',
#   29,
#   29.2,
#   '29.20',
#   'Výroba karoserií motorových vozidel; výroba přívěsů a\xa0návěsů'],
#  ['C',
#   29,
#   29.3,
#   '',
#   'Výroba dílů a příslušenství pro motorová vozidla a jejich motory'],
#  ['C',
#   29,
#   29.3,
#   29.31,
#   'Výroba elektrického a elektronického zařízení pro\xa0motorová vozidla'],
#  ['C',
#   29,
#   29.3,
#   29.32,
#   'Výroba ostatních dílů a příslušenství pro motorová vozidla'],
#  ['C', 30, '', '', 'Výroba ostatních dopravních prostředků a zařízení'],
#  ['C', 30, 30.1, '', 'Stavba lodí a člunů'],
#  ['C', 30, 30.1, 30.11, 'Stavba lodí a plavidel'],
#  ['C', 30, 30.1, 30.12, 'Stavba rekreačních a sportovních člunů'],
#  ['C', 30, 30.2, '', 'Výroba železničních lokomotiv a vozového parku'],
#  ['C', 30, 30.2, '30.20', 'Výroba železničních lokomotiv a vozového parku'],
#  ['C',
#   30,
#   30.3,
#   '',
#   'Výroba letadel a jejich motorů, kosmických lodí a souvisejících zařízení'],
#  ['C',
#   30,
#   30.3,
#   '30.30',
#   'Výroba letadel a jejich motorů, kosmických lodí a souvisejících zařízení'],
#  ['C', 30, 30.4, '', 'Výroba vojenských bojových vozidel'],
#  ['C', 30, 30.4, '30.40', 'Výroba vojenských bojových vozidel'],
#  ['C', 30, 30.9, '', 'Výroba dopravních prostředků a zařízení j. n.'],
#  ['C', 30, 30.9, 30.91, 'Výroba motocyklů'],
#  ['C', 30, 30.9, 30.92, 'Výroba jízdních kol a vozíků pro invalidy'],
#  ['C',
#   30,
#   30.9,
#   30.99,
#   'Výroba ostatních dopravních prostředků a zařízení j. n.'],
#  ['C', 31, '', '', 'Výroba nábytku'],
#  ['C', 31, 31.0, '', 'Výroba nábytku'],
#  ['C', 31, 31.0, 31.01, 'Výroba kancelářského nábytku a zařízení obchodů'],
#  ['C', 31, 31.0, 31.02, 'Výroba kuchyňského nábytku'],
#  ['C', 31, 31.0, 31.03, 'Výroba matrací'],
#  ['C', 31, 31.0, 31.09, 'Výroba ostatního nábytku'],
#  ['C', 32, '', '', 'Ostatní zpracovatelský průmysl'],
#  ['C', 32, 32.1, '', 'Výroba klenotů, bižuterie a\xa0příbuzných výrobků'],
#  ['C', 32, 32.1, 32.11, 'Ražení mincí'],
#  ['C', 32, 32.1, 32.12, 'Výroba klenotů a příbuzných výrobků'],
#  ['C', 32, 32.1, 32.13, 'Výroba bižuterie a příbuzných výrobků'],
#  ['C', 32, 32.2, '', 'Výroba hudebních nástrojů'],
#  ['C', 32, 32.2, '32.20', 'Výroba hudebních nástrojů'],
#  ['C', 32, 32.3, '', 'Výroba sportovních potřeb'],
#  ['C', 32, 32.3, '32.30', 'Výroba sportovních potřeb'],
#  ['C', 32, 32.4, '', 'Výroba her a hraček'],
#  ['C', 32, 32.4, '32.40', 'Výroba her a hraček'],
#  ['C', 32, 32.5, '', 'Výroba lékařských a dentálních nástrojů a potřeb'],
#  ['C', 32, 32.5, '32.50', 'Výroba lékařských a dentálních nástrojů a potřeb'],
#  ['C', 32, 32.9, '', 'Zpracovatelský průmysl j. n.'],
#  ['C', 32, 32.9, 32.91, 'Výroba košťat a kartáčnických výrobků'],
#  ['C', 32, 32.9, 32.99, 'Ostatní zpracovatelský průmysl j. n.'],
#  ['C', 33, '', '', 'Opravy a instalace strojů a zařízení'],
#  ['C', 33, 33.1, '', 'Opravy kovodělných výrobků, strojů a zařízení'],
#  ['C', 33, 33.1, 33.11, 'Opravy kovodělných výrobků'],
#  ['C', 33, 33.1, 33.12, 'Opravy strojů'],
#  ['C',
#   33,
#   33.1,
#   33.13,
#   'Opravy elektronických a optických přístrojů a zařízení'],
#  ['C', 33, 33.1, 33.14, 'Opravy elektrických zařízení'],
#  ['C', 33, 33.1, 33.15, 'Opravy a údržba lodí a člunů'],
#  ['C', 33, 33.1, 33.16, 'Opravy a údržba letadel a kosmických lodí'],
#  ['C', 33, 33.1, '33.17.1', 'Opravy a údržba kolejových vozidel'],
#  ['C',
#   33,
#   33.1,
#   '33.17.9',
#   'Opravy a údržba ostatních dopravních prostředků a zařízení j. n. kromě kolejových vozidel'],
#  ['C',
#   33,
#   33.1,
#   33.17,
#   'Opravy a údržba ostatních dopravních prostředků a zařízení j. n.'],
#  ['C', 33, 33.1, 33.19, 'Opravy ostatních zařízení'],
#  ['C', 33, 33.2, '', 'Instalace průmyslových strojů a zařízení'],
#  ['C', 33, 33.2, '33.20', 'Instalace průmyslových strojů a zařízení'],
#  ['D',
#   '',
#   '',
#   '',
#   'SEKCE D – VÝROBA A ROZVOD ELEKTŘINY, PLYNU, TEPLA A\xa0KLIMATIZOVANÉHO VZDUCHU'],
#  ['D',
#   35,
#   '',
#   '',
#   'Výroba a rozvod elektřiny, plynu, tepla a klimatizovaného vzduchu'],
#  ['D', 35, 35.1, '', 'Výroba, přenos a rozvod elektřiny'],
#  ['D', 35, 35.1, 35.11, 'Výroba elektřiny'],
#  ['D', 35, 35.1, 35.12, 'Přenos elektřiny'],
#  ['D', 35, 35.1, 35.13, 'Rozvod elektřiny'],
#  ['D', 35, 35.1, 35.14, 'Obchod s elektřinou'],
#  ['D',
#   35,
#   35.2,
#   '',
#   'Výroba plynu; rozvod plynných paliv prostřednictvím sítí'],
#  ['D', 35, 35.2, 35.21, 'Výroba plynu'],
#  ['D', 35, 35.2, 35.22, 'Rozvod plynných paliv prostřednictvím sítí'],
#  ['D', 35, 35.2, 35.23, 'Obchod s\xa0plynem prostřednictvím sítí'],
#  ['D',
#   35,
#   35.3,
#   '',
#   'Výroba a rozvod tepla a klimatizovaného vzduchu, výroba ledu'],
#  ['D', 35, 35.3, '35.30.1', 'Výroba tepla'],
#  ['D', 35, 35.3, '35.30.2', 'Rozvod tepla'],
#  ['D', 35, 35.3, '35.30.3', 'Výroba klimatizovaného vzduchu'],
#  ['D', 35, 35.3, '35.30.4', 'Rozvod klimatizovaného vzduchu'],
#  ['D', 35, 35.3, '35.30.5', 'Výroba chladicí vody'],
#  ['D', 35, 35.3, '35.30.6', 'Rozvod chladicí vody'],
#  ['D', 35, 35.3, '35.30.7', 'Výroba ledu'],
#  ['D',
#   35,
#   35.3,
#   '35.30',
#   'Výroba a rozvod tepla a klimatizovaného vzduchu, výroba ledu'],
#  ['E',
#   '',
#   '',
#   '',
#   'SEKCE E – ZÁSOBOVÁNÍ VODOU; ČINNOSTI SOUVISEJÍCÍ S\xa0ODPADNÍMI VODAMI, ODPADY A SANACEMI'],
#  ['E', 36, '', '', 'Shromažďování, úprava a rozvod vody'],
#  ['E', 36, 36.0, '', 'Shromažďování, úprava a rozvod vody'],
#  ['E', 36, 36.0, '36.00', 'Shromažďování, úprava a rozvod vody'],
#  ['E', 37, '', '', 'Činnosti související s\xa0odpadními vodami'],
#  ['E', 37, 37.0, '', 'Činnosti související s\xa0odpadními vodami'],
#  ['E', 37, 37.0, '37.00', 'Činnosti související s\xa0odpadními vodami'],
#  ['E',
#   38,
#   '',
#   '',
#   'Shromažďování, sběr a odstraňování odpadů, úprava odpadů k dalšímu využití'],
#  ['E', 38, 38.1, '', 'Shromažďování a sběr odpadů'],
#  ['E', 38, 38.1, 38.11, 'Shromažďování a sběr odpadů, kromě nebezpečných'],
#  ['E', 38, 38.1, 38.12, 'Shromažďování a sběr nebezpečných odpadů'],
#  ['E', 38, 38.2, '', 'Odstraňování odpadů'],
#  ['E', 38, 38.2, 38.21, 'Odstraňování odpadů, kromě nebezpečných'],
#  ['E', 38, 38.2, 38.22, 'Odstraňování nebezpečných odpadů'],
#  ['E', 38, 38.3, '', 'Úprava odpadů k dalšímu využití'],
#  ['E',
#   38,
#   38.3,
#   38.31,
#   'Demontáž vraků a vyřazených strojů a zařízení pro účely recyklace'],
#  ['E',
#   38,
#   38.3,
#   38.32,
#   'Úprava odpadů k dalšímu využití, kromě demontáže vraků, strojů a zařízení'],
#  ['E', 39, '', '', 'Sanace a jiné činnosti související s odpady'],
#  ['E', 39, 39.0, '', 'Sanace a jiné činnosti související s odpady'],
#  ['E', 39, 39.0, '39.00', 'Sanace a jiné činnosti související s odpady'],
#  ['F', '', '', '', 'SEKCE F - STAVEBNICTVÍ'],
#  ['F', 41, '', '', 'Výstavba budov'],
#  ['F', 41, 41.1, '', 'Developerská činnost'],
#  ['F', 41, 41.1, '41.10', 'Developerská činnost'],
#  ['F', 41, 41.2, '', 'Výstavba bytových a nebytových budov'],
#  ['F', 41, 41.2, '41.20.1', 'Výstavba bytových budov'],
#  ['F', 41, 41.2, '41.20.2', 'Výstavba nebytových budov'],
#  ['F', 41, 41.2, '41.20', 'Výstavba bytových a nebytových budov'],
#  ['F', 42, '', '', 'Inženýrské stavitelství'],
#  ['F', 42, 42.1, '', 'Výstavba silnic a železnic'],
#  ['F', 42, 42.1, 42.11, 'Výstavba silnic a dálnic'],
#  ['F', 42, 42.1, 42.12, 'Výstavba železnic a podzemních drah'],
#  ['F', 42, 42.1, 42.13, 'Výstavba mostů a tunelů'],
#  ['F', 42, 42.2, '', 'Výstavba inženýrských sítí'],
#  ['F', 42, 42.2, '42.21.1', 'Výstavba inženýrských sítí pro kapaliny'],
#  ['F', 42, 42.2, '42.21.2', 'Výstavba inženýrských sítí pro plyny'],
#  ['F', 42, 42.2, 42.21, 'Výstavba inženýrských sítí pro kapaliny a plyny'],
#  ['F',
#   42,
#   42.2,
#   42.22,
#   'Výstavba inženýrských sítí pro elektřinu a\xa0telekomunikace'],
#  ['F', 42, 42.9, '', 'Výstavba ostatních staveb'],
#  ['F', 42, 42.9, 42.91, 'Výstavba vodních děl'],
#  ['F', 42, 42.9, 42.99, 'Výstavba ostatních staveb j. n.'],
#  ['F', 43, '', '', 'Specializované stavební činnosti'],
#  ['F', 43, 43.1, '', 'Demolice a příprava staveniště'],
#  ['F', 43, 43.1, 43.11, 'Demolice'],
#  ['F', 43, 43.1, 43.12, 'Příprava staveniště'],
#  ['F', 43, 43.1, 43.13, 'Průzkumné vrtné práce'],
#  ['F',
#   43,
#   43.2,
#   '',
#   'Elektroinstalační, instalatérské a ostatní stavebně instalační práce'],
#  ['F', 43, 43.2, 43.21, 'Elektrické instalace'],
#  ['F', 43, 43.2, 43.22, 'Instalace vody, odpadu, plynu, topení a klimatizace'],
#  ['F', 43, 43.2, 43.29, 'Ostatní stavební instalace'],
#  ['F', 43, 43.3, '', 'Kompletační a dokončovací práce'],
#  ['F', 43, 43.3, 43.31, 'Omítkářské práce'],
#  ['F', 43, 43.3, 43.32, 'Truhlářské práce'],
#  ['F', 43, 43.3, 43.33, 'Obkládání stěn a pokládání podlahových krytin'],
#  ['F', 43, 43.3, '43.34.1', 'Sklenářské práce'],
#  ['F', 43, 43.3, '43.34.2', 'Malířské a natěračské práce'],
#  ['F', 43, 43.3, 43.34, 'Sklenářské, malířské a natěračské práce'],
#  ['F', 43, 43.3, 43.39, 'Ostatní kompletační a dokončovací práce'],
#  ['F', 43, 43.9, '', 'Ostatní specializované stavební činnosti'],
#  ['F', 43, 43.9, 43.91, 'Pokrývačské práce'],
#  ['F', 43, 43.9, '43.99.1', 'Montáž a demontáž lešení a bednění'],
#  ['F', 43, 43.9, '43.99.9', 'Jiné specializované stavební činnosti j. n.'],
#  ['F', 43, 43.9, 43.99, 'Ostatní specializované stavební činnosti j. n.'],
#  ['G',
#   '',
#   '',
#   '',
#   'SEKCE G - VELKOOBCHOD A MALOOBCHOD; OPRAVY A\xa0ÚDRŽBA MOTOROVÝCH VOZIDEL'],
#  ['G', 45, '', '', 'Velkoobchod, maloobchod a opravy motorových vozidel'],
#  ['G', 45, 45.1, '', 'Obchod s motorovými vozidly, kromě motocyklů'],
#  ['G',
#   45,
#   45.1,
#   45.11,
#   'Obchod s\xa0automobily a jinými lehkými motorovými vozidly'],
#  ['G',
#   45,
#   45.1,
#   45.19,
#   'Obchod s\xa0ostatními motorovými vozidly, kromě motocyklů'],
#  ['G', 45, 45.2, '', 'Opravy a údržba motorových vozidel, kromě motocyklů'],
#  ['G',
#   45,
#   45.2,
#   '45.20',
#   'Opravy a údržba motorových vozidel, kromě motocyklů'],
#  ['G',
#   45,
#   45.3,
#   '',
#   'Obchod s díly a příslušenstvím pro motorová vozidla, kromě motocyklů'],
#  ['G',
#   45,
#   45.3,
#   45.31,
#   'Velkoobchod s díly a příslušenstvím pro motorová vozidla, kromě motocyklů'],
#  ['G',
#   45,
#   45.3,
#   45.32,
#   'Maloobchod s díly a příslušenstvím pro motorová vozidla, kromě motocyklů'],
#  ['G',
#   45,
#   45.4,
#   '',
#   'Obchod, opravy a údržba motocyklů, jejich dílů a\xa0příslušenství'],
#  ['G',
#   45,
#   45.4,
#   '45.40',
#   'Obchod, opravy a údržba motocyklů, jejich dílů a\xa0příslušenství'],
#  ['G', 46, '', '', 'Velkoobchod, kromě motorových vozidel'],
#  ['G',
#   46,
#   46.1,
#   '',
#   'Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení'],
#  ['G',
#   46,
#   46.1,
#   46.11,
#   'Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení se základními zemědělskými produkty, živými zvířaty, textilními surovinami a polotovary'],
#  ['G',
#   46,
#   46.1,
#   46.12,
#   'Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s\xa0palivy, rudami, kovy a průmyslovými chemikáliemi'],
#  ['G',
#   46,
#   46.1,
#   46.13,
#   'Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení se dřevem a stavebními materiály'],
#  ['G',
#   46,
#   46.1,
#   46.14,
#   'Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení se stroji, průmyslovým zařízením, loděmi a letadly'],
#  ['G',
#   46,
#   46.1,
#   46.15,
#   'Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s\xa0nábytkem, železářským zbožím a\xa0potřebami převážně pro\xa0domácnost'],
#  ['G',
#   46,
#   46.1,
#   46.16,
#   'Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s\xa0textilem, oděvy, kožešinami, obuví a\xa0koženými výrobky'],
#  ['G',
#   46,
#   46.1,
#   46.17,
#   'Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s potravinami, nápoji, tabákem a\xa0tabákovými výrobky'],
#  ['G',
#   46,
#   46.1,
#   '46.18.1',
#   'Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s\xa0papírenskými výrobky'],
#  ['G',
#   46,
#   46.1,
#   '46.18.9',
#   'Zprostředkování specializovaného velkoobchodu a velkoobchod v\xa0zastoupení s\xa0ostatními výrobky j. n.'],
#  ['G',
#   46,
#   46.1,
#   46.18,
#   'Zprostředkování specializovaného velkoobchodu a specializovaný velkoobchod v\xa0zastoupení s\xa0ostatními výrobky'],
#  ['G',
#   46,
#   46.1,
#   46.19,
#   'Zprostředkování nespecializovaného velkoobchodu a nespecializovaný velkoobchod v\xa0zastoupení'],
#  ['G',
#   46,
#   46.2,
#   '',
#   'Velkoobchod se základními zemědělskými produkty a živými zvířaty'],
#  ['G',
#   46,
#   46.2,
#   46.21,
#   'Velkoobchod s\xa0obilím, surovým tabákem, osivy a\xa0krmivy'],
#  ['G', 46, 46.2, 46.22, 'Velkoobchod s\xa0květinami a jinými rostlinami'],
#  ['G', 46, 46.2, 46.23, 'Velkoobchod s živými zvířaty'],
#  ['G',
#   46,
#   46.2,
#   46.24,
#   'Velkoobchod se surovými kůžemi, kožešinami a\xa0usněmi'],
#  ['G',
#   46,
#   46.3,
#   '',
#   'Velkoobchod s\xa0potravinami, nápoji a tabákovými výrobky'],
#  ['G', 46, 46.3, 46.31, 'Velkoobchod s\xa0ovocem a zeleninou'],
#  ['G', 46, 46.3, 46.32, 'Velkoobchod s\xa0masem a masnými výrobky'],
#  ['G',
#   46,
#   46.3,
#   46.33,
#   'Velkoobchod s mléčnými výrobky, vejci, jedlými oleji a tuky'],
#  ['G', 46, 46.3, 46.34, 'Velkoobchod s nápoji'],
#  ['G', 46, 46.3, 46.35, 'Velkoobchod s\xa0tabákovými výrobky'],
#  ['G', 46, 46.3, 46.36, 'Velkoobchod s\xa0cukrem, čokoládou a cukrovinkami'],
#  ['G', 46, 46.3, 46.37, 'Velkoobchod s\xa0kávou, čajem, kakaem a kořením'],
#  ['G',
#   46,
#   46.3,
#   46.38,
#   'Specializovaný velkoobchod s\xa0jinými potravinami, včetně\xa0ryb, korýšů a\xa0měkkýšů'],
#  ['G',
#   46,
#   46.3,
#   46.39,
#   'Nespecializovaný velkoobchod s\xa0potravinami, nápoji a\xa0tabákovými výrobky'],
#  ['G', 46, 46.4, '', 'Velkoobchod s\xa0výrobky převážně pro domácnost'],
#  ['G', 46, 46.4, 46.41, 'Velkoobchod s\xa0textilem'],
#  ['G', 46, 46.4, '46.42.1', 'Velkoobchod s oděvy'],
#  ['G', 46, 46.4, '46.42.2', 'Velkoobchod s obuví'],
#  ['G', 46, 46.4, 46.42, 'Velkoobchod s\xa0oděvy a obuví'],
#  ['G', 46, 46.4, 46.43, 'Velkoobchod s\xa0elektrospotřebiči a elektronikou'],
#  ['G',
#   46,
#   46.4,
#   '46.44.1',
#   'Velkoobchod s\xa0porcelánovými, keramickými a skleněnými výrobky'],
#  ['G', 46, 46.4, '46.44.2', 'Velkoobchod s\xa0pracími a čisticími prostředky'],
#  ['G',
#   46,
#   46.4,
#   46.44,
#   'Velkoobchod s\xa0porcelánovými, keramickými a skleněnými výrobky a\xa0čisticími prostředky'],
#  ['G', 46, 46.4, 46.45, 'Velkoobchod s\xa0kosmetickými výrobky'],
#  ['G', 46, 46.4, 46.46, 'Velkoobchod s\xa0farmaceutickými výrobky'],
#  ['G', 46, 46.4, 46.47, 'Velkoobchod s\xa0nábytkem, koberci a svítidly'],
#  ['G', 46, 46.4, 46.48, 'Velkoobchod s\xa0hodinami, hodinkami a klenoty'],
#  ['G',
#   46,
#   46.4,
#   46.49,
#   'Velkoobchod s\xa0ostatními výrobky převážně pro\xa0domácnost'],
#  ['G', 46, 46.5, '', 'Velkoobchod s\xa0počítačovým a komunikačním zařízením'],
#  ['G',
#   46,
#   46.5,
#   46.51,
#   'Velkoobchod s\xa0počítači, počítačovým periferním zařízením a softwarem'],
#  ['G',
#   46,
#   46.5,
#   46.52,
#   'Velkoobchod s\xa0elektronickým a telekomunikačním zařízením a jeho díly'],
#  ['G',
#   46,
#   46.6,
#   '',
#   'Velkoobchod s ostatními stroji, strojním zařízením a příslušenstvím'],
#  ['G',
#   46,
#   46.6,
#   46.61,
#   'Velkoobchod se zemědělskými stroji, strojním zařízením a příslušenstvím'],
#  ['G', 46, 46.6, 46.62, 'Velkoobchod s\xa0obráběcími stroji'],
#  ['G',
#   46,
#   46.6,
#   46.63,
#   'Velkoobchod s\xa0těžebními a stavebními stroji a\xa0zařízením'],
#  ['G',
#   46,
#   46.6,
#   46.64,
#   'Velkoobchod se strojním zařízením pro textilní průmysl, šicími a pletacími stroji'],
#  ['G', 46, 46.6, 46.65, 'Velkoobchod s\xa0kancelářským nábytkem'],
#  ['G',
#   46,
#   46.6,
#   46.66,
#   'Velkoobchod s\xa0ostatními kancelářskými stroji a\xa0zařízením'],
#  ['G', 46, 46.6, 46.69, 'Velkoobchod s\xa0ostatními stroji a zařízením'],
#  ['G', 46, 46.7, '', 'Ostatní specializovaný velkoobchod'],
#  ['G',
#   46,
#   46.7,
#   '46.71.1',
#   'Velkoobchod s pevnými palivy a příbuznými výrobky'],
#  ['G',
#   46,
#   46.7,
#   '46.71.2',
#   'Velkoobchod s kapalnými palivy a příbuznými výrobky'],
#  ['G',
#   46,
#   46.7,
#   '46.71.3',
#   'Velkoobchod s plynnými palivy a příbuznými výrobky'],
#  ['G',
#   46,
#   46.7,
#   46.71,
#   'Velkoobchod s\xa0pevnými, kapalnými a plynnými palivy a příbuznými výrobky'],
#  ['G', 46, 46.7, 46.72, 'Velkoobchod s\xa0rudami, kovy a hutními výrobky'],
#  ['G',
#   46,
#   46.7,
#   46.73,
#   'Velkoobchod se dřevem, stavebními materiály a\xa0sanitárním vybavením'],
#  ['G',
#   46,
#   46.7,
#   46.74,
#   'Velkoobchod s\xa0železářským zbožím, instalatérskými a\xa0topenářskými potřebami'],
#  ['G', 46, 46.7, 46.75, 'Velkoobchod s\xa0chemickými výrobky'],
#  ['G', 46, 46.7, '46.76.1', 'Velkoobchod s\xa0papírenskými meziprodukty'],
#  ['G', 46, 46.7, '46.76.9', 'Velkoobchod s\xa0ostatními meziprodukty j. n.'],
#  ['G', 46, 46.7, 46.76, 'Velkoobchod s\xa0ostatními meziprodukty'],
#  ['G', 46, 46.7, 46.77, 'Velkoobchod s\xa0odpadem a šrotem'],
#  ['G', 46, 46.9, '', 'Nespecializovaný velkoobchod'],
#  ['G', 46, 46.9, '46.90', 'Nespecializovaný velkoobchod'],
#  ['G', 47, '', '', 'Maloobchod, kromě motorových vozidel'],
#  ['G', 47, 47.1, '', 'Maloobchod v\xa0nespecializovaných prodejnách'],
#  ['G',
#   47,
#   47.1,
#   47.11,
#   'Maloobchod s\xa0převahou potravin, nápojů a tabákových výrobků v\xa0nespecializovaných prodejnách'],
#  ['G', 47, 47.1, 47.19, 'Ostatní maloobchod v nespecializovaných prodejnách'],
#  ['G',
#   47,
#   47.2,
#   '',
#   'Maloobchod s potravinami, nápoji a tabákovými výrobky ve\xa0specializovaných prodejnách'],
#  ['G', 47, 47.2, 47.21, 'Maloobchod s\xa0ovocem a zeleninou'],
#  ['G', 47, 47.2, 47.22, 'Maloobchod s\xa0masem a masnými výrobky'],
#  ['G', 47, 47.2, 47.23, 'Maloobchod s\xa0rybami, korýši a měkkýši'],
#  ['G',
#   47,
#   47.2,
#   47.24,
#   'Maloobchod s\xa0chlebem, pečivem, cukrářskými výrobky a cukrovinkami'],
#  ['G', 47, 47.2, 47.25, 'Maloobchod s\xa0nápoji'],
#  ['G', 47, 47.2, 47.26, 'Maloobchod s tabákovými výrobky'],
#  ['G',
#   47,
#   47.2,
#   47.29,
#   'Ostatní maloobchod s\xa0potravinami ve specializovaných prodejnách'],
#  ['G',
#   47,
#   47.3,
#   '',
#   'Maloobchod s pohonnými hmotami ve\xa0specializovaných prodejnách'],
#  ['G',
#   47,
#   47.3,
#   '47.30',
#   'Maloobchod s pohonnými hmotami ve\xa0specializovaných prodejnách'],
#  ['G',
#   47,
#   47.4,
#   '',
#   'Maloobchod s\xa0počítačovým a komunikačním zařízením ve\xa0specializovaných prodejnách'],
#  ['G',
#   47,
#   47.4,
#   47.41,
#   'Maloobchod s\xa0počítači, počítačovým periferním zařízením a softwarem'],
#  ['G', 47, 47.4, 47.42, 'Maloobchod s telekomunikačním zařízením'],
#  ['G', 47, 47.4, 47.43, 'Maloobchod s audio- a videozařízením'],
#  ['G',
#   47,
#   47.5,
#   '',
#   'Maloobchod s\xa0ostatními výrobky převážně pro\xa0domácnost ve\xa0specializovaných prodejnách'],
#  ['G', 47, 47.5, 47.51, 'Maloobchod s\xa0textilem'],
#  ['G',
#   47,
#   47.5,
#   47.52,
#   'Maloobchod s\xa0železářským zbožím, barvami, sklem a\xa0potřebami pro kutily'],
#  ['G',
#   47,
#   47.5,
#   47.53,
#   'Maloobchod s\xa0koberci, podlahovými krytinami a\xa0nástěnnými obklady'],
#  ['G', 47, 47.5, 47.54, 'Maloobchod s\xa0elektrospotřebiči a elektronikou'],
#  ['G',
#   47,
#   47.5,
#   47.59,
# ...
#  ['J',
#   59,
#   59.1,
#   59.13,
#   'Distribuce filmů, videozáznamů a televizních programů'],
#  ['J', 59, 59.1, 59.14, 'Promítání filmů'],
#  ['J',
#   59,
#   59.2,
#   '',
#   'Pořizování zvukových nahrávek a hudební vydavatelské činnosti'],
#  ['J',
#   59,
#   59.2,
#   '59.20',
#   'Pořizování zvukových nahrávek a hudební vydavatelské činnosti'],
#  ['J', 60, '', '', 'Tvorba programů a vysílání'],
#  ['J', 60, 60.1, '', 'Rozhlasové vysílání'],
#  ['J', 60, 60.1, '60.10', 'Rozhlasové vysílání'],
#  ['J', 60, 60.2, '', 'Tvorba televizních programů a televizní vysílání'],
#  ['J', 60, 60.2, '60.20', 'Tvorba televizních programů a televizní vysílání'],
#  ['J', 61, '', '', 'Telekomunikační činnosti'],
#  ['J', 61, 61.1, '', 'Činnosti související s\xa0pevnou telekomunikační sítí'],
#  ['J',
#   61,
#   61.1,
#   '61.10.1',
#   'Poskytování hlasových služeb přes pevnou telekomunikační síť'],
#  ['J', 61, 61.1, '61.10.2', 'Pronájem pevné telekomunikační sítě'],
#  ['J', 61, 61.1, '61.10.3', 'Přenos dat přes pevnou telekomunikační síť'],
#  ['J',
#   61,
#   61.1,
#   '61.10.4',
#   'Poskytování přístupu k\xa0internetu přes pevnou telekomunikační síť'],
#  ['J',
#   61,
#   61.1,
#   '61.10.9',
#   'Ostatní činnosti související s\xa0pevnou telekomunikační sítí'],
#  ['J',
#   61,
#   61.1,
#   '61.10',
#   'Činnosti související s\xa0pevnou telekomunikační sítí'],
#  ['J',
#   61,
#   61.2,
#   '',
#   'Činnosti související s bezdrátovou telekomunikační sítí'],
#  ['J',
#   61,
#   61.2,
#   '61.20.1',
#   'Poskytování hlasových služeb přes bezdrátovou telekomunikační síť'],
#  ['J', 61, 61.2, '61.20.2', 'Pronájem bezdrátové telekomunikační sítě'],
#  ['J', 61, 61.2, '61.20.3', 'Přenos dat přes bezdrátovou telekomunikační síť'],
#  ['J',
#   61,
#   61.2,
#   '61.20.4',
#   'Poskytování přístupu k\xa0internetu přes bezdrátovou telekomunikační síť'],
#  ['J',
#   61,
#   61.2,
#   '61.20.9',
#   'Ostatní činnosti související s\xa0bezdrátovou telekomunikační sítí'],
#  ['J',
#   61,
#   61.2,
#   '61.20',
#   'Činnosti související s bezdrátovou telekomunikační sítí'],
#  ['J', 61, 61.3, '', 'Činnosti související se satelitní telekomunikační sítí'],
#  ['J',
#   61,
#   61.3,
#   '61.30',
#   'Činnosti související se satelitní telekomunikační sítí'],
#  ['J', 61, 61.9, '', 'Ostatní telekomunikační činnosti'],
#  ['J', 61, 61.9, '61.90', 'Ostatní telekomunikační činnosti'],
#  ['J', 62, '', '', 'Činnosti v oblasti informačních technologií'],
#  ['J', 62, 62.0, '', 'Činnosti v oblasti informačních technologií'],
#  ['J', 62, 62.0, 62.01, 'Programování'],
#  ['J', 62, 62.0, 62.02, 'Poradenství v\xa0oblasti informačních technologií'],
#  ['J', 62, 62.0, 62.03, 'Správa počítačového vybavení'],
#  ['J',
#   62,
#   62.0,
#   62.09,
#   'Ostatní činnosti v\xa0oblasti informačních technologií'],
#  ['J', 63, '', '', 'Informační činnosti'],
#  ['J',
#   63,
#   63.1,
#   '',
#   'Činnosti související se zpracováním dat a hostingem; činnosti související s webovými portály'],
#  ['J', 63, 63.1, 63.11, 'Činnosti související se zpracováním dat a hostingem'],
#  ['J', 63, 63.1, 63.12, 'Činnosti související s webovými portály'],
#  ['J', 63, 63.9, '', 'Ostatní informační činnosti'],
#  ['J',
#   63,
#   63.9,
#   63.91,
#   'Činnosti zpravodajských tiskových kanceláří a agentur'],
#  ['J', 63, 63.9, 63.99, 'Ostatní informační činnosti j. n.'],
#  ['K', '', '', '', 'SEKCE K - PENĚŽNICTVÍ A POJIŠŤOVNICTVÍ'],
#  ['K',
#   64,
#   '',
#   '',
#   'Finanční zprostředkování, kromě pojišťovnictví a\xa0penzijního financování'],
#  ['K', 64, 64.1, '', 'Peněžní zprostředkování'],
#  ['K', 64, 64.1, 64.11, 'Centrální bankovnictví'],
#  ['K', 64, 64.1, 64.19, 'Ostatní peněžní zprostředkování'],
#  ['K', 64, 64.2, '', 'Činnosti holdingových společností'],
#  ['K', 64, 64.2, '64.20', 'Činnosti holdingových společností'],
#  ['K', 64, 64.3, '', 'Činnosti trustů, fondů a podobných finančních subjektů'],
#  ['K',
#   64,
#   64.3,
#   '64.30',
#   'Činnosti trustů, fondů a podobných finančních subjektů'],
#  ['K', 64, 64.9, '', 'Ostatní finanční zprostředkování'],
#  ['K', 64, 64.9, 64.91, 'Finanční leasing'],
#  ['K',
#   64,
#   64.9,
#   '64.92.1',
#   'Poskytování úvěrů společnostmi, které nepřijímají vklady'],
#  ['K', 64, 64.9, '64.92.2', 'Poskytování obchodních úvěrů'],
#  ['K', 64, 64.9, '64.92.3', 'Činnosti zastaváren'],
#  ['K', 64, 64.9, '64.92.9', 'Ostatní poskytování úvěrů j. n.'],
#  ['K', 64, 64.9, 64.92, 'Ostatní poskytování úvěrů'],
#  ['K', 64, 64.9, '64.99.1', 'Faktoringové činnosti'],
#  ['K', 64, 64.9, '64.99.2', 'Obchodování s\xa0cennými papíry na vlastní účet'],
#  ['K', 64, 64.9, '64.99.9', 'Jiné finanční zprostředkování j. n.'],
#  ['K', 64, 64.9, 64.99, 'Ostatní finanční zprostředkování j. n.'],
#  ['K',
#   65,
#   '',
#   '',
#   'Pojištění, zajištění a penzijní financování, kromě\xa0povinného sociálního zabezpečení'],
#  ['K', 65, 65.1, '', 'Pojištění'],
#  ['K', 65, 65.1, 65.11, 'Životní pojištění'],
#  ['K', 65, 65.1, 65.12, 'Neživotní pojištění'],
#  ['K', 65, 65.2, '', 'Zajištění'],
#  ['K', 65, 65.2, '65.20', 'Zajištění'],
#  ['K', 65, 65.3, '', 'Penzijní financování'],
#  ['K', 65, 65.3, '65.30', 'Penzijní financování'],
#  ['K', 66, '', '', 'Ostatní finanční činnosti'],
#  ['K',
#   66,
#   66.1,
#   '',
#   'Pomocné činnosti související s\xa0finančním zprostředkováním, kromě pojišťovnictví a\xa0penzijního financování'],
#  ['K', 66, 66.1, 66.11, 'Řízení a správa finančních trhů'],
#  ['K',
#   66,
#   66.1,
#   66.12,
#   'Obchodování s\xa0cennými papíry a komoditami na\xa0burzách'],
#  ['K',
#   66,
#   66.1,
#   66.19,
#   'Ostatní pomocné činnosti související s finančním zprostředkováním'],
#  ['K',
#   66,
#   66.2,
#   '',
#   'Pomocné činnosti související s\xa0pojišťovnictvím a\xa0penzijním financováním'],
#  ['K', 66, 66.2, 66.21, 'Vyhodnocování rizik a škod'],
#  ['K', 66, 66.2, 66.22, 'Činnosti zástupců pojišťovny a makléřů'],
#  ['K',
#   66,
#   66.2,
#   66.29,
#   'Ostatní pomocné činnosti související s\xa0pojišťovnictvím a penzijním financováním'],
#  ['K', 66, 66.3, '', 'Správa fondů'],
#  ['K', 66, 66.3, '66.30', 'Správa fondů'],
#  ['L', '', '', '', 'SEKCE L - ČINNOSTI V\xa0OBLASTI NEMOVITOSTÍ'],
#  ['L', 68, '', '', 'Činnosti v oblasti nemovitostí'],
#  ['L', 68, 68.1, '', 'Nákup a následný prodej vlastních nemovitostí'],
#  ['L', 68, 68.1, '68.10', 'Nákup a následný prodej vlastních nemovitostí'],
#  ['L',
#   68,
#   68.2,
#   '',
#   'Pronájem a správa vlastních nebo\xa0pronajatých nemovitostí'],
#  ['L',
#   68,
#   68.2,
#   '68.20.1',
#   'Pronájem vlastních nebo pronajatých nemovitostí s\xa0bytovými prostory'],
#  ['L',
#   68,
#   68.2,
#   '68.20.2',
#   'Pronájem vlastních nebo pronajatých nemovitostí s\xa0nebytovými prostory'],
#  ['L',
#   68,
#   68.2,
#   '68.20.3',
#   'Správa vlastních nebo pronajatých nemovitostí s\xa0bytovými prostory'],
#  ['L',
#   68,
#   68.2,
#   '68.20.4',
#   'Správa vlastních nebo pronajatých nemovitostí s\xa0nebytovými prostory'],
#  ['L',
#   68,
#   68.2,
#   '68.20',
#   'Pronájem a správa vlastních nebo pronajatých nemovitostí'],
#  ['L',
#   68,
#   68.3,
#   '',
#   'Činnosti v\xa0oblasti nemovitostí na základě smlouvy nebo dohody'],
#  ['L', 68, 68.3, 68.31, 'Zprostředkovatelské činnosti realitních agentur'],
#  ['L', 68, 68.3, 68.32, 'Správa nemovitostí na základě smlouvy'],
#  ['M', '', '', '', 'SEKCE M - PROFESNÍ, VĚDECKÉ A\xa0TECHNICKÉ ČINNOSTI'],
#  ['M', 69, '', '', 'Právní a účetnické činnosti'],
#  ['M', 69, 69.1, '', 'Právní činnosti'],
#  ['M', 69, 69.1, '69.10', 'Právní činnosti'],
#  ['M', 69, 69.2, '', 'Účetnické a auditorské činnosti; daňové poradenství'],
#  ['M',
#   69,
#   69.2,
#   '69.20',
#   'Účetnické a auditorské činnosti; daňové poradenství'],
#  ['M', 70, '', '', 'Činnosti vedení podniků; poradenství v\xa0oblasti řízení'],
#  ['M', 70, 70.1, '', 'Činnosti vedení podniků'],
#  ['M', 70, 70.1, '70.10', 'Činnosti vedení podniků'],
#  ['M', 70, 70.2, '', 'Poradenství v\xa0oblasti řízení'],
#  ['M',
#   70,
#   70.2,
#   70.21,
#   'Poradenství v\xa0oblasti vztahů s\xa0veřejností a komunikace'],
#  ['M', 70, 70.2, 70.22, 'Ostatní poradenství v\xa0oblasti podnikání a řízení'],
#  ['M',
#   71,
#   '',
#   '',
#   'Architektonické a inženýrské činnosti; technické zkoušky a analýzy'],
#  ['M',
#   71,
#   71.1,
#   '',
#   'Architektonické a inženýrské činnosti a související technické poradenství'],
#  ['M', 71, 71.1, 71.11, 'Architektonické činnosti'],
#  ['M', 71, 71.1, '71.12.1', 'Geologický průzkum'],
#  ['M', 71, 71.1, '71.12.2', 'Zeměměřické a kartografické činnosti'],
#  ['M', 71, 71.1, '71.12.3', 'Hydrometeorologické a meteorologické činnosti'],
#  ['M',
#   71,
#   71.1,
#   '71.12.9',
#   'Ostatní inženýrské činnosti a související technické poradenství j. n.'],
#  ['M',
#   71,
#   71.1,
#   71.12,
#   'Inženýrské činnosti a související technické poradenství'],
#  ['M', 71, 71.2, '', 'Technické zkoušky a analýzy'],
#  ['M',
#   71,
#   71.2,
#   '71.20.1',
#   'Zkoušky a analýzy vyhrazených technických zařízení'],
#  ['M', 71, 71.2, '71.20.9', 'Ostatní technické zkoušky a analýzy'],
#  ['M', 71, 71.2, '71.20', 'Technické zkoušky a analýzy'],
#  ['M', 72, '', '', 'Výzkum a vývoj'],
#  ['M',
#   72,
#   72.1,
#   '',
#   'Výzkum a vývoj v\xa0oblasti přírodních a technických věd'],
#  ['M', 72, 72.1, 72.11, 'Výzkum a vývoj v\xa0oblasti biotechnologie'],
#  ['M', 72, 72.1, '72.19.1', 'Výzkum a vývoj v oblasti lékařských věd'],
#  ['M', 72, 72.1, '72.19.2', 'Výzkum a vývoj v\xa0oblasti technických věd'],
#  ['M',
#   72,
#   72.1,
#   '72.19.9',
#   'Výzkum a vývoj v\xa0oblasti jiných přírodních věd'],
#  ['M',
#   72,
#   72.1,
#   72.19,
#   'Ostatní výzkum a vývoj v\xa0oblasti přírodních a\xa0technických věd'],
#  ['M',
#   72,
#   72.2,
#   '',
#   'Výzkum a vývoj v\xa0oblasti společenských a\xa0humanitních věd'],
#  ['M',
#   72,
#   72.2,
#   '72.20',
#   'Výzkum a vývoj v\xa0oblasti společenských a\xa0humanitních věd'],
#  ['M', 73, '', '', 'Reklama a průzkum trhu'],
#  ['M', 73, 73.1, '', 'Reklamní činnosti'],
#  ['M', 73, 73.1, 73.11, 'Činnosti reklamních agentur'],
#  ['M',
#   73,
#   73.1,
#   73.12,
#   'Zastupování médií při prodeji reklamního času a\xa0prostoru'],
#  ['M', 73, 73.2, '', 'Průzkum trhu a veřejného mínění'],
#  ['M', 73, 73.2, '73.20', 'Průzkum trhu a veřejného mínění'],
#  ['M', 74, '', '', 'Ostatní profesní, vědecké a technické činnosti'],
#  ['M', 74, 74.1, '', 'Specializované návrhářské činnosti'],
#  ['M', 74, 74.1, '74.10', 'Specializované návrhářské činnosti'],
#  ['M', 74, 74.2, '', 'Fotografické činnosti'],
#  ['M', 74, 74.2, '74.20', 'Fotografické činnosti'],
#  ['M', 74, 74.3, '', 'Překladatelské a tlumočnické činnosti'],
#  ['M', 74, 74.3, '74.30', 'Překladatelské a tlumočnické činnosti'],
#  ['M', 74, 74.9, '', 'Ostatní profesní, vědecké a technické činnosti j. n.'],
#  ['M',
#   74,
#   74.9,
#   '74.90.1',
#   'Poradenství v\xa0oblasti bezpečnosti a ochrany zdraví při práci'],
#  ['M', 74, 74.9, '74.90.2', 'Poradenství v\xa0oblasti požární ochrany'],
#  ['M',
#   74,
#   74.9,
#   '74.90.9',
#   'Jiné profesní, vědecké a technické činnosti j. n.'],
#  ['M',
#   74,
#   74.9,
#   '74.90',
#   'Ostatní profesní, vědecké a technické činnosti j. n.'],
#  ['M', 75, '', '', 'Veterinární činnosti'],
#  ['M', 75, 75.0, '', 'Veterinární činnosti'],
#  ['M', 75, 75.0, '75.00', 'Veterinární činnosti'],
#  ['N', '', '', '', 'SEKCE N - ADMINISTRATIVNÍ A PODPŮRNÉ ČINNOSTI'],
#  ['N', 77, '', '', 'Činnosti v\xa0oblasti pronájmu a operativního leasingu'],
#  ['N', 77, 77.1, '', 'Pronájem a leasing motorových vozidel, kromě motocyklů'],
#  ['N',
#   77,
#   77.1,
#   77.11,
#   'Pronájem a leasing\xa0automobilů a jiných lehkých motorových vozidel, kromě motocyklů'],
#  ['N', 77, 77.1, 77.12, 'Pronájem a leasing nákladních automobilů'],
#  ['N',
#   77,
#   77.2,
#   '',
#   'Pronájem a leasing výrobků pro osobní potřebu a\xa0převážně pro\xa0domácnost'],
#  ['N', 77, 77.2, 77.21, 'Pronájem a leasing rekreačních a sportovních potřeb'],
#  ['N', 77, 77.2, 77.22, 'Pronájem videokazet a disků'],
#  ['N',
#   77,
#   77.2,
#   77.29,
#   'Pronájem a leasing ostatních výrobků pro osobní potřebu a převážně pro\xa0domácnost'],
#  ['N',
#   77,
#   77.3,
#   '',
#   'Pronájem a leasing ostatních strojů, zařízení a\xa0výrobků'],
#  ['N', 77, 77.3, 77.31, 'Pronájem a leasing zemědělských strojů a zařízení'],
#  ['N', 77, 77.3, 77.32, 'Pronájem a leasing stavebních strojů a\xa0zařízení'],
#  ['N',
#   77,
#   77.3,
#   77.33,
#   'Pronájem a leasing kancelářských strojů a zařízení, včetně\xa0počítačů'],
#  ['N', 77, 77.3, 77.34, 'Pronájem a leasing vodních dopravních prostředků'],
#  ['N', 77, 77.3, 77.35, 'Pronájem a leasing leteckých dopravních prostředků'],
#  ['N',
#   77,
#   77.3,
#   77.39,
#   'Pronájem a leasing ostatních strojů, zařízení a výrobků j. n.'],
#  ['N',
#   77,
#   77.4,
#   '',
#   'Leasing duševního vlastnictví a podobných produktů, kromě děl chráněných autorským právem'],
#  ['N',
#   77,
#   77.4,
#   '77.40',
#   'Leasing duševního vlastnictví a podobných produktů, kromě děl chráněných autorským právem'],
#  ['N', 78, '', '', 'Činnosti související se zaměstnáním'],
#  ['N', 78, 78.1, '', 'Činnosti agentur zprostředkujících zaměstnání'],
#  ['N', 78, 78.1, '78.10', 'Činnosti agentur zprostředkujících zaměstnání'],
#  ['N',
#   78,
#   78.2,
#   '',
#   'Činnosti agentur zprostředkujících práci na přechodnou dobu'],
#  ['N',
#   78,
#   78.2,
#   '78.20',
#   'Činnosti agentur zprostředkujících práci na přechodnou dobu'],
#  ['N', 78, 78.3, '', 'Ostatní poskytování lidských zdrojů'],
#  ['N', 78, 78.3, '78.30', 'Ostatní poskytování lidských zdrojů'],
#  ['N',
#   79,
#   '',
#   '',
#   'Činnosti cestovních agentur, kanceláří a jiné rezervační a související činnosti'],
#  ['N', 79, 79.1, '', 'Činnosti cestovních agentur a cestovních kanceláří'],
#  ['N', 79, 79.1, 79.11, 'Činnosti cestovních agentur'],
#  ['N', 79, 79.1, 79.12, 'Činnosti cestovních kanceláří'],
#  ['N', 79, 79.9, '', 'Ostatní rezervační a související činnosti'],
#  ['N', 79, 79.9, '79.90.1', 'Průvodcovské činnosti'],
#  ['N', 79, 79.9, '79.90.9', 'Ostatní rezervační a související činnosti j. n.'],
#  ['N', 79, 79.9, '79.90', 'Ostatní rezervační a související činnosti'],
#  ['N', 80, '', '', 'Bezpečnostní a pátrací činnosti'],
#  ['N', 80, 80.1, '', 'Činnosti soukromých bezpečnostních agentur'],
#  ['N', 80, 80.1, '80.10', 'Činnosti soukromých bezpečnostních agentur'],
#  ['N',
#   80,
#   80.2,
#   '',
#   'Činnosti související s\xa0provozem bezpečnostních systémů'],
#  ['N',
#   80,
#   80.2,
#   '80.20',
#   'Činnosti související s\xa0provozem bezpečnostních systémů'],
#  ['N', 80, 80.3, '', 'Pátrací činnosti'],
#  ['N', 80, 80.3, '80.30', 'Pátrací činnosti'],
#  ['N', 81, '', '', 'Činnosti související se\xa0stavbami a úpravou krajiny'],
#  ['N', 81, 81.1, '', 'Kombinované pomocné činnosti'],
#  ['N', 81, 81.1, '81.10', 'Kombinované pomocné činnosti'],
#  ['N', 81, 81.2, '', 'Úklidové činnosti'],
#  ['N', 81, 81.2, 81.21, 'Všeobecný úklid budov'],
#  ['N',
#   81,
#   81.2,
#   81.22,
#   'Specializované čištění a úklid budov a průmyslových zařízení'],
#  ['N', 81, 81.2, 81.29, 'Ostatní úklidové činnosti'],
#  ['N', 81, 81.3, '', 'Činnosti související s\xa0úpravou krajiny'],
#  ['N', 81, 81.3, '81.30', 'Činnosti související s\xa0úpravou krajiny'],
#  ['N',
#   82,
#   '',
#   '',
#   'Administrativní, kancelářské a jiné podpůrné činnosti pro podnikání'],
#  ['N', 82, 82.1, '', 'Administrativní a kancelářské činnosti'],
#  ['N', 82, 82.1, 82.11, 'Univerzální administrativní činnosti'],
#  ['N',
#   82,
#   82.1,
#   82.19,
#   'Kopírování, příprava dokumentů a ostatní specializované kancelářské podpůrné činnosti'],
#  ['N',
#   82,
#   82.2,
#   '',
#   'Činnosti zprostředkovatelských středisek po\xa0telefonu'],
#  ['N',
#   82,
#   82.2,
#   '82.20',
#   'Činnosti zprostředkovatelských středisek po telefonu'],
#  ['N', 82, 82.3, '', 'Pořádání konferencí a hospodářských výstav'],
#  ['N', 82, 82.3, '82.30', 'Pořádání konferencí a hospodářských výstav'],
#  ['N', 82, 82.9, '', 'Podpůrné činnosti pro podnikání j. n.'],
#  ['N', 82, 82.9, 82.91, 'Inkasní činnosti, ověřování solventnosti zákazníka'],
#  ['N', 82, 82.9, 82.92, 'Balicí činnosti'],
#  ['N', 82, 82.9, 82.99, 'Ostatní podpůrné činnosti pro podnikání j. n.'],
#  ['O',
#   '',
#   '',
#   '',
#   'SEKCE O - VEŘEJNÁ SPRÁVA A OBRANA; POVINNÉ SOCIÁLNÍ ZABEZPEČENÍ'],
#  ['O', 84, '', '', 'Veřejná správa a obrana; povinné sociální zabezpečení'],
#  ['O', 84, 84.1, '', 'Veřejná správa a hospodářská a sociální politika'],
#  ['O', 84, 84.1, 84.11, 'Všeobecné činnosti veřejné správy'],
#  ['O',
#   84,
#   84.1,
#   84.12,
#   'Regulace činností souvisejících s poskytováním zdravotní péče, vzděláváním, kulturou a sociální péčí, kromě sociálního zabezpečení'],
#  ...]

# %%
len(data)
# Out:
# 1156

# %%
df = pd.DataFrame(data=data, columns=columns)

# %%
df
# Out:
#      sekce oddil skupina  trida  \
# 0        A
# 1        A    01
# 2        A    01    01.1
# 3        A    01    01.1  01.11
# 4        A    01    01.1  01.12
# ...    ...   ...     ...    ...
# 1151     T    98    98.2  98.20
# 1152     U
# 1153     U    99
# 1154     U    99    99.0
# 1155     U    99    99.0  99.00
#
#                                                   nazev
# 0          SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A RYBÁŘSTVÍ
# 1     Rostlinná a živočišná výroba, myslivost a souv...
# 2                  Pěstování plodin jiných než trvalých
# 3     Pěstování obilovin (kromě rýže), luštěnin a ol...
# 4                                        Pěstování rýže
# ...                                                 ...
# 1151  Činnosti domácností poskytujících blíže neurče...
# 1152  SEKCE U - ČINNOSTI EXTERITORIÁLNÍCH ORGANIZACÍ...
# 1153      Činnosti exteritoriálních organizací a orgánů
# 1154      Činnosti exteritoriálních organizací a orgánů
# 1155      Činnosti exteritoriálních organizací a orgánů
#
# [1156 rows x 5 columns]

# %%
#df.drop(columns=[''], inplace=True)
df
# Out:
#      sekce oddil skupina  trida  \
# 0        A
# 1        A    01
# 2        A    01    01.1
# 3        A    01    01.1  01.11
# 4        A    01    01.1  01.12
# ...    ...   ...     ...    ...
# 1151     T    98    98.2  98.20
# 1152     U
# 1153     U    99
# 1154     U    99    99.0
# 1155     U    99    99.0  99.00
#
#                                                   nazev
# 0          SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A RYBÁŘSTVÍ
# 1     Rostlinná a živočišná výroba, myslivost a souv...
# 2                  Pěstování plodin jiných než trvalých
# 3     Pěstování obilovin (kromě rýže), luštěnin a ol...
# 4                                        Pěstování rýže
# ...                                                 ...
# 1151  Činnosti domácností poskytujících blíže neurče...
# 1152  SEKCE U - ČINNOSTI EXTERITORIÁLNÍCH ORGANIZACÍ...
# 1153      Činnosti exteritoriálních organizací a orgánů
# 1154      Činnosti exteritoriálních organizací a orgánů
# 1155      Činnosti exteritoriálních organizací a orgánů
#
# [1156 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sekce    1156 non-null   object
#  1   oddil    1156 non-null   object
#  2   skupina  1156 non-null   object
#  3   trida    1156 non-null   object
#  4   nazev    1156 non-null   object
# dtypes: object(5)
# memory usage: 45.3+ KB

# %%
df[df['oddil'] == '']
# Out:
#      sekce oddil skupina trida  \
# 0        A
# 60       B
# 103      C
# 472      D
# 492      E
# 512      F
# 555      G
# 689      H
# 745      I
# 772      J
# 828      K
# 867      L
# 880      M
# 934      N
# 995      O
# 1012     P
# 1042     Q
# 1079     R
# 1106     S
# 1143     T
# 1152     U
#
#                                                   nazev
# 0          SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A RYBÁŘSTVÍ
# 60                           SEKCE B - TĚŽBA A DOBÝVÁNÍ
# 103                    SEKCE C - ZPRACOVATELSKÝ PRŮMYSL
# 472   SEKCE D – VÝROBA A ROZVOD ELEKTŘINY, PLYNU, TE...
# 492   SEKCE E – ZÁSOBOVÁNÍ VODOU; ČINNOSTI SOUVISEJÍ...
# 512                              SEKCE F - STAVEBNICTVÍ
# 555   SEKCE G - VELKOOBCHOD A MALOOBCHOD; OPRAVY A Ú...
# 689                      SEKCE H - DOPRAVA A SKLADOVÁNÍ
# 745      SEKCE I - UBYTOVÁNÍ, STRAVOVÁNÍ A POHOSTINSTVÍ
# 772         SEKCE J - INFORMAČNÍ A KOMUNIKAČNÍ ČINNOSTI
# 828              SEKCE K - PENĚŽNICTVÍ A POJIŠŤOVNICTVÍ
# 867            SEKCE L - ČINNOSTI V OBLASTI NEMOVITOSTÍ
# 880    SEKCE M - PROFESNÍ, VĚDECKÉ A TECHNICKÉ ČINNOSTI
# 934       SEKCE N - ADMINISTRATIVNÍ A PODPŮRNÉ ČINNOSTI
# 995   SEKCE O - VEŘEJNÁ SPRÁVA A OBRANA; POVINNÉ SOC...
# 1012                               SEKCE P – VZDĚLÁVÁNÍ
# 1042                SEKCE Q - ZDRAVOTNÍ A SOCIÁLNÍ PÉČE
# 1079   SEKCE R - KULTURNÍ, ZÁBAVNÍ A REKREAČNÍ ČINNOSTI
# 1106                         SEKCE S - OSTATNÍ ČINNOSTI
# 1143  SEKCE T - ČINNOSTI DOMÁCNOSTÍ JAKO ZAMĚSTNAVAT...
# 1152  SEKCE U - ČINNOSTI EXTERITORIÁLNÍCH ORGANIZACÍ...

# %%
for i in df[df['oddil'] == ''].items():
    #print(type(i[0]), type(i[1]))
    #print(i[0], i[1].name)
    if i[0] == 'sekce':
        for j in i[1].items():
            print(j)
    if i[0] == 'nazev':
        for j in i[1].items():
            print(j)
# Out:
# (0, 'A')
# (60, 'B')
# (103, 'C')
# (472, 'D')
# (492, 'E')
# (512, 'F')
# (555, 'G')
# (689, 'H')
# (745, 'I')
# (772, 'J')
# (828, 'K')
# (867, 'L')
# (880, 'M')
# (934, 'N')
# (995, 'O')
# (1012, 'P')
# (1042, 'Q')
# (1079, 'R')
# (1106, 'S')
# (1143, 'T')
# (1152, 'U')
# (0, 'SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A\xa0RYBÁŘSTVÍ')
# (60, 'SEKCE B - TĚŽBA A DOBÝVÁNÍ')
# (103, 'SEKCE C - ZPRACOVATELSKÝ PRŮMYSL')
# (472, 'SEKCE D – VÝROBA A ROZVOD ELEKTŘINY, PLYNU, TEPLA A\xa0KLIMATIZOVANÉHO VZDUCHU')
# (492, 'SEKCE E – ZÁSOBOVÁNÍ VODOU; ČINNOSTI SOUVISEJÍCÍ S\xa0ODPADNÍMI VODAMI, ODPADY A SANACEMI')
# (512, 'SEKCE F - STAVEBNICTVÍ')
# (555, 'SEKCE G - VELKOOBCHOD A MALOOBCHOD; OPRAVY A\xa0ÚDRŽBA MOTOROVÝCH VOZIDEL')
# (689, 'SEKCE H - DOPRAVA A SKLADOVÁNÍ')
# (745, 'SEKCE I - UBYTOVÁNÍ, STRAVOVÁNÍ A\xa0POHOSTINSTVÍ')
# (772, 'SEKCE J - INFORMAČNÍ A KOMUNIKAČNÍ ČINNOSTI')
# (828, 'SEKCE K - PENĚŽNICTVÍ A POJIŠŤOVNICTVÍ')
# (867, 'SEKCE L - ČINNOSTI V\xa0OBLASTI NEMOVITOSTÍ')
# (880, 'SEKCE M - PROFESNÍ, VĚDECKÉ A\xa0TECHNICKÉ ČINNOSTI')
# (934, 'SEKCE N - ADMINISTRATIVNÍ A PODPŮRNÉ ČINNOSTI')
# (995, 'SEKCE O - VEŘEJNÁ SPRÁVA A OBRANA; POVINNÉ SOCIÁLNÍ ZABEZPEČENÍ')
# (1012, 'SEKCE P – VZDĚLÁVÁNÍ')
# (1042, 'SEKCE Q - ZDRAVOTNÍ A SOCIÁLNÍ PÉČE')
# (1079, 'SEKCE R - KULTURNÍ, ZÁBAVNÍ A\xa0REKREAČNÍ ČINNOSTI')
# (1106, 'SEKCE S - OSTATNÍ ČINNOSTI')
# (1143, 'SEKCE T - ČINNOSTI DOMÁCNOSTÍ JAKO\xa0ZAMĚSTNAVATELŮ; ČINNOSTI DOMÁCNOSTÍ PRODUKUJÍCÍCH BLÍŽE NEURČENÉ VÝROBKY A SLUŽBY PRO\xa0VLASTNÍ POTŘEBU')
# (1152, 'SEKCE U - ČINNOSTI EXTERITORIÁLNÍCH ORGANIZACÍ A\xa0ORGÁNŮ')

# %%
from collections import namedtuple
nace = namedtuple('nace', ['sekce', 'nazev'])
naces = []
for i in df[df['oddil'] == ''].index:
    #print(type(i[0]), type(i[1]))
    #print(i[0], i[1].name)
    naces.append(nace(df.iloc[i].sekce, df.iloc[i].nazev))

# %%
naces
# Out:
# [nace(sekce='A', nazev='SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A\xa0RYBÁŘSTVÍ'),
#  nace(sekce='B', nazev='SEKCE B - TĚŽBA A DOBÝVÁNÍ'),
#  nace(sekce='C', nazev='SEKCE C - ZPRACOVATELSKÝ PRŮMYSL'),
#  nace(sekce='D', nazev='SEKCE D – VÝROBA A ROZVOD ELEKTŘINY, PLYNU, TEPLA A\xa0KLIMATIZOVANÉHO VZDUCHU'),
#  nace(sekce='E', nazev='SEKCE E – ZÁSOBOVÁNÍ VODOU; ČINNOSTI SOUVISEJÍCÍ S\xa0ODPADNÍMI VODAMI, ODPADY A SANACEMI'),
#  nace(sekce='F', nazev='SEKCE F - STAVEBNICTVÍ'),
#  nace(sekce='G', nazev='SEKCE G - VELKOOBCHOD A MALOOBCHOD; OPRAVY A\xa0ÚDRŽBA MOTOROVÝCH VOZIDEL'),
#  nace(sekce='H', nazev='SEKCE H - DOPRAVA A SKLADOVÁNÍ'),
#  nace(sekce='I', nazev='SEKCE I - UBYTOVÁNÍ, STRAVOVÁNÍ A\xa0POHOSTINSTVÍ'),
#  nace(sekce='J', nazev='SEKCE J - INFORMAČNÍ A KOMUNIKAČNÍ ČINNOSTI'),
#  nace(sekce='K', nazev='SEKCE K - PENĚŽNICTVÍ A POJIŠŤOVNICTVÍ'),
#  nace(sekce='L', nazev='SEKCE L - ČINNOSTI V\xa0OBLASTI NEMOVITOSTÍ'),
#  nace(sekce='M', nazev='SEKCE M - PROFESNÍ, VĚDECKÉ A\xa0TECHNICKÉ ČINNOSTI'),
#  nace(sekce='N', nazev='SEKCE N - ADMINISTRATIVNÍ A PODPŮRNÉ ČINNOSTI'),
#  nace(sekce='O', nazev='SEKCE O - VEŘEJNÁ SPRÁVA A OBRANA; POVINNÉ SOCIÁLNÍ ZABEZPEČENÍ'),
#  nace(sekce='P', nazev='SEKCE P – VZDĚLÁVÁNÍ'),
#  nace(sekce='Q', nazev='SEKCE Q - ZDRAVOTNÍ A SOCIÁLNÍ PÉČE'),
#  nace(sekce='R', nazev='SEKCE R - KULTURNÍ, ZÁBAVNÍ A\xa0REKREAČNÍ ČINNOSTI'),
#  nace(sekce='S', nazev='SEKCE S - OSTATNÍ ČINNOSTI'),
#  nace(sekce='T', nazev='SEKCE T - ČINNOSTI DOMÁCNOSTÍ JAKO\xa0ZAMĚSTNAVATELŮ; ČINNOSTI DOMÁCNOSTÍ PRODUKUJÍCÍCH BLÍŽE NEURČENÉ VÝROBKY A SLUŽBY PRO\xa0VLASTNÍ POTŘEBU'),
#  nace(sekce='U', nazev='SEKCE U - ČINNOSTI EXTERITORIÁLNÍCH ORGANIZACÍ A\xa0ORGÁNŮ')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sekce    1156 non-null   object
#  1   oddil    1156 non-null   object
#  2   skupina  1156 non-null   object
#  3   trida    1156 non-null   object
#  4   nazev    1156 non-null   object
# dtypes: object(5)
# memory usage: 45.3+ KB

# %%
#df['trida_nazev'] = df[['trida', 'nazev']].agg(' '.join, axis=1) #nejde!!!
df['skupina1'] = df['trida']
df.loc[df['skupina1'] == '', 'skupina1'] = df[df['skupina1'] == '']['skupina']
df['nazev1'] = df[['skupina1', 'nazev']].astype(str).agg(' '.join, axis=1)

# %%
df
# Out:
#      sekce oddil skupina  trida  \
# 0        A
# 1        A    01
# 2        A    01    01.1
# 3        A    01    01.1  01.11
# 4        A    01    01.1  01.12
# ...    ...   ...     ...    ...
# 1151     T    98    98.2  98.20
# 1152     U
# 1153     U    99
# 1154     U    99    99.0
# 1155     U    99    99.0  99.00
#
#                                                   nazev skupina1  \
# 0          SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A RYBÁŘSTVÍ
# 1     Rostlinná a živočišná výroba, myslivost a souv...
# 2                  Pěstování plodin jiných než trvalých     01.1
# 3     Pěstování obilovin (kromě rýže), luštěnin a ol...    01.11
# 4                                        Pěstování rýže    01.12
# ...                                                 ...      ...
# 1151  Činnosti domácností poskytujících blíže neurče...    98.20
# 1152  SEKCE U - ČINNOSTI EXTERITORIÁLNÍCH ORGANIZACÍ...
# 1153      Činnosti exteritoriálních organizací a orgánů
# 1154      Činnosti exteritoriálních organizací a orgánů     99.0
# 1155      Činnosti exteritoriálních organizací a orgánů    99.00
#
#                                                  nazev1
# 0          SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A RYBÁŘSTVÍ
# 1      Rostlinná a živočišná výroba, myslivost a sou...
# 2             01.1 Pěstování plodin jiných než trvalých
# 3     01.11 Pěstování obilovin (kromě rýže), luštěni...
# 4                                  01.12 Pěstování rýže
# ...                                                 ...
# 1151  98.20 Činnosti domácností poskytujících blíže ...
# 1152   SEKCE U - ČINNOSTI EXTERITORIÁLNÍCH ORGANIZAC...
# 1153      Činnosti exteritoriálních organizací a orgánů
# 1154  99.0 Činnosti exteritoriálních organizací a or...
# 1155  99.00 Činnosti exteritoriálních organizací a o...
#
# [1156 rows x 7 columns]

# %%
naces_dict = {}
for nace in naces:
    #print(nace.nazev)
    naces_dict[nace.nazev]=df[(df['sekce']==nace.sekce) & ((df['skupina'] != '') | (df['trida'] != ''))].nazev1.unique()

# %%
naces_dict
# Out:
# {'SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A\xa0RYBÁŘSTVÍ': array(['01.1 Pěstování plodin jiných než trvalých',
#         '01.11 Pěstování obilovin (kromě rýže), luštěnin a olejnatých semen',
#         '01.12 Pěstování rýže',
#         '01.13 Pěstování zeleniny a melounů, kořenů a hlíz',
#         '01.14 Pěstování cukrové třtiny', '01.15 Pěstování tabáku',
#         '01.16 Pěstování přadných rostlin',
#         '01.19 Pěstování ostatních plodin jiných než trvalých',
#         '01.2 Pěstování trvalých plodin', '01.21 Pěstování vinných hroznů',
#         '01.22 Pěstování tropického a subtropického ovoce',
#         '01.23 Pěstování citrusových plodů',
#         '01.24 Pěstování jádrového a peckového ovoce',
#         '01.25 Pěstování ostatního stromového a keřového ovoce a\xa0ořechů',
#         '01.26 Pěstování olejnatých plodů',
#         '01.27 Pěstování rostlin pro výrobu nápojů',
#         '01.28 Pěstování koření, aromatických, léčivých a\xa0farmaceutických rostlin',
#         '01.29 Pěstování ostatních trvalých plodin',
#         '01.3 Množení rostlin', '01.30 Množení rostlin',
#         '01.4 Živočišná výroba', '01.41 Chov mléčného skotu',
#         '01.42 Chov jiného skotu', '01.43 Chov koní a jiných koňovitých',
#         '01.44 Chov velbloudů a velbloudovitých', '01.45 Chov ovcí a koz',
#         '01.46 Chov prasat', '01.47 Chov drůbeže',
#         '01.49.1 Chov drobných hospodářských zvířat',
#         '01.49.2 Chov kožešinových zvířat',
#         '01.49.3 Chov zvířat pro zájmový chov',
#         '01.49.9 Chov ostatních zvířat j. n.',
#         '01.49 Chov ostatních zvířat', '01.5 Smíšené hospodářství',
#         '01.50 Smíšené hospodářství',
#         '01.6 Podpůrné činnosti pro zemědělství a posklizňové činnosti',
#         '01.61 Podpůrné činnosti pro rostlinnou výrobu',
#         '01.62 Podpůrné činnosti pro živočišnou výrobu',
#         '01.63 Posklizňové činnosti',
#         '01.64 Zpracování osiva pro účely množení',
#         '01.7 Lov a odchyt divokých zvířat a související činnosti',
#         '01.70 Lov a odchyt divokých zvířat a související činnosti',
#         '02.1 Lesní hospodářství a jiné činnosti v oblasti lesnictví',
#         '02.10 Lesní hospodářství a jiné činnosti v oblasti lesnictví',
#         '02.2 Těžba dřeva', '02.20 Těžba dřeva',
#         '02.3 Sběr a získávání volně rostoucích plodů a\xa0materiálů, kromě dřeva',
#         '02.30 Sběr a získávání volně rostoucích plodů a\xa0materiálů, kromě dřeva',
#         '02.4 Podpůrné činnosti pro lesnictví',
#         '02.40 Podpůrné činnosti pro lesnictví', '03.1 Rybolov',
#         '03.11 Mořský rybolov', '03.12 Sladkovodní rybolov',
#         '03.2 Akvakultura', '03.21 Mořská akvakultura',
#         '03.22 Sladkovodní akvakultura'], dtype=object),
#  'SEKCE B - TĚŽBA A DOBÝVÁNÍ': array(['05.1 Těžba a úprava černého uhlí', '05.10.1 Těžba černého uhlí',
#         '05.10.2 Úprava černého uhlí', '05.10 Těžba a úprava černého uhlí',
#         '05.2 Těžba a úprava hnědého uhlí',
#         '05.20.1 Těžba hnědého uhlí, kromě lignitu',
#         '05.20.2 Úprava hnědého uhlí, kromě lignitu',
#         '05.20.3 Těžba lignitu', '05.20.4 Úprava lignitu',
#         '05.20 Těžba a úprava hnědého uhlí', '06.1 Těžba ropy',
#         '06.10 Těžba ropy', '06.2 Těžba zemního plynu',
#         '06.20 Těžba zemního plynu', '07.1 Těžba a úprava železných rud',
#         '07.10.1 Těžba železných rud', '07.10.2 Úprava železných rud',
#         '07.10 Těžba a úprava železných rud',
#         '07.2 Těžba a úprava neželezných rud',
#         '07.21.1 Těžba uranových a thoriových rud',
#         '07.21.2 Úprava uranových a thoriových rud',
#         '07.21 Těžba a úprava uranových a thoriových rud',
#         '07.29.1 Těžba ostatních neželezných rud',
#         '07.29.2 Úprava ostatních neželezných rud',
#         '07.29 Těžba a úprava ostatních neželezných rud',
#         '08.1 Dobývání kamene, písků a jílů',
#         '08.11 Dobývání kamene pro výtvarné nebo stavební účely, vápence, sádrovce, křídy a břidlice',
#         '08.12 Provoz pískoven a štěrkopískoven; těžba jílů a kaolinu',
#         '08.9 Těžba a dobývání j. n.',
#         '08.91 Těžba chemických minerálů a minerálů pro výrobu hnojiv',
#         '08.92 Těžba rašeliny', '08.93 Těžba soli',
#         '08.99 Ostatní těžba a dobývání j. n.',
#         '09.1 Podpůrné činnosti při těžbě ropy a zemního plynu',
#         '09.10 Podpůrné činnosti při těžbě ropy a zemního plynu',
#         '09.9 Podpůrné činnosti při ostatní těžbě a dobývání',
#         '09.90 Podpůrné činnosti při ostatní těžbě a dobývání'],
#        dtype=object),
#  'SEKCE C - ZPRACOVATELSKÝ PRŮMYSL': array(['10.1 Zpracování a konzervování masa a výroba masných výrobků',
#         '10.11 Zpracování a konzervování masa, kromě drůbežího',
#         '10.12 Zpracování a konzervování drůbežího masa',
#         '10.13 Výroba masných výrobků a výrobků z\xa0drůbežího masa',
#         '10.2 Zpracování a konzervování ryb, korýšů a měkkýšů',
#         '10.20 Zpracování a konzervování ryb, korýšů a měkkýšů',
#         '10.3 Zpracování a konzervování ovoce a zeleniny',
#         '10.31 Zpracování a konzervování brambor',
#         '10.32 Výroba ovocných a zeleninových šťáv',
#         '10.39 Ostatní zpracování a konzervování ovoce a zeleniny',
#         '10.4 Výroba rostlinných a živočišných olejů a tuků',
#         '10.41 Výroba olejů a tuků',
#         '10.42 Výroba margarínu a podobných jedlých tuků',
#         '10.5 Výroba mléčných výrobků',
#         '10.51 Zpracování mléka, výroba mléčných výrobků a sýrů',
#         '10.52 Výroba zmrzliny',
#         '10.6 Výroba mlýnských a škrobárenských výrobků',
#         '10.61 Výroba mlýnských výrobků',
#         '10.62 Výroba škrobárenských výrobků',
#         '10.7 Výroba pekařských, cukrářských a jiných moučných výrobků',
#         '10.71 Výroba pekařských a cukrářských výrobků, kromě trvanlivých',
#         '10.72 Výroba sucharů a sušenek; výroba trvanlivých cukrářských výrobků',
#         '10.73 Výroba makaronů, nudlí, kuskusu a podobných moučných výrobků',
#         '10.8 Výroba ostatních potravinářských výrobků',
#         '10.81 Výroba cukru', '10.82 Výroba kakaa, čokolády a cukrovinek',
#         '10.83 Zpracování čaje a kávy',
#         '10.84 Výroba koření a aromatických výtažků',
#         '10.85 Výroba hotových pokrmů',
#         '10.86 Výroba homogenizovaných potravinářských přípravků a dietních potravin',
#         '10.89 Výroba ostatních potravinářských výrobků j. n.',
#         '10.9 Výroba průmyslových krmiv',
#         '10.91 Výroba průmyslových krmiv pro hospodářská zvířata',
#         '10.92 Výroba průmyslových krmiv pro zvířata v\xa0zájmovém chovu',
#         '11.0 Výroba nápojů',
#         '11.01 Destilace, rektifikace a míchání lihovin',
#         '11.02 Výroba vína z\xa0vinných hroznů',
#         '11.03 Výroba jablečného vína a jiných ovocných vín',
#         '11.04 Výroba ostatních nedestilovaných kvašených nápojů',
#         '11.05 Výroba piva', '11.06 Výroba sladu',
#         '11.07 Výroba nealkoholických nápojů; stáčení minerálních a\xa0ostatních vod do\xa0lahví',
#         '12.0 Výroba tabákových výrobků',
#         '12.00 Výroba tabákových výrobků',
#         '13.1 Úprava a spřádání textilních vláken a příze',
#         '13.10 Úprava a spřádání textilních vláken a příze',
#         '13.2 Tkaní textilií', '13.20 Tkaní textilií',
#         '13.3 Konečná úprava textilií', '13.30 Konečná úprava textilií',
#         '13.9 Výroba ostatních textilií',
#         '13.91 Výroba pletených a háčkovaných materiálů',
#         '13.92 Výroba konfekčních textilních výrobků, kromě oděvů',
#         '13.93 Výroba koberců a kobercových předložek',
#         '13.94 Výroba lan, provazů a síťovaných výrobků',
#         '13.95 Výroba netkaných textilií a výrobků z\xa0nich, kromě oděvů',
#         '13.96 Výroba ostatních technických a průmyslových textilií',
#         '13.99 Výroba ostatních textilií j. n.',
#         '14.1 Výroba oděvů, kromě kožešinových výrobků',
#         '14.11 Výroba kožených oděvů', '14.12 Výroba pracovních oděvů',
#         '14.13 Výroba ostatních svrchních oděvů',
#         '14.14 Výroba osobního prádla',
#         '14.19 Výroba ostatních oděvů a oděvních doplňků',
#         '14.2 Výroba kožešinových výrobků',
#         '14.20 Výroba kožešinových výrobků',
#         '14.3 Výroba pletených a háčkovaných oděvů',
#         '14.31 Výroba pletených a háčkovaných punčochových výrobků',
#         '14.39 Výroba ostatních pletených a háčkovaných oděvů',
#         '15.1 Činění a úprava usní (vyčiněných kůží); zpracování a\xa0barvení kožešin; výroba brašnářských,\xa0sedlářských a podobných výrobků',
#         '15.11 Činění a úprava usní (vyčiněných kůží); zpracování a\xa0barvení kožešin',
#         '15.12 Výroba brašnářských, sedlářských a podobných výrobků',
#         '15.2 Výroba obuvi', '15.20.1 Výroba obuvi s\xa0usňovým svrškem',
#         '15.20.9 Výroba obuvi z\xa0ostatních materiálů',
#         '15.20 Výroba obuvi', '16.1 Výroba pilařská a impregnace dřeva',
#         '16.10 Výroba pilařská a impregnace dřeva',
#         '16.2 Výroba dřevěných, korkových, proutěných a\xa0slaměných výrobků, kromě nábytku',
#         '16.21 Výroba dýh a desek na bázi dřeva',
#         '16.22 Výroba sestavených parketových podlah',
#         '16.23 Výroba ostatních výrobků stavebního truhlářství a\xa0tesařství',
#         '16.24 Výroba dřevěných obalů',
#         '16.29 Výroba ostatních dřevěných, korkových, proutěných a slaměných výrobků, kromě nábytku',
#         '17.1 Výroba buničiny, papíru a lepenky',
#         '17.11.1 Výroba chemických buničin',
#         '17.11.2 Výroba mechanických vláknin',
#         '17.11.3 Výroba ostatních papírenských vláknin',
#         '17.11 Výroba buničiny', '17.12 Výroba papíru a lepenky',
#         '17.2 Výroba výrobků z papíru a lepenky',
#         '17.21 Výroba vlnitého papíru a lepenky, papírových a\xa0lepenkových obalů',
#         '17.22 Výroba domácích potřeb, hygienických a toaletních výrobků z papíru',
#         '17.23 Výroba kancelářských potřeb z papíru', '17.24 Výroba tapet',
#         '17.29 Výroba ostatních výrobků z papíru a lepenky',
#         '18.1 Tisk a činnosti související s tiskem', '18.11 Tisk novin',
#         '18.12 Tisk ostatní, kromě novin',
#         '18.13 Příprava tisku a digitálních dat',
#         '18.14 Vázání a související činnosti',
#         '18.2 Rozmnožování nahraných nosičů',
#         '18.20 Rozmnožování nahraných nosičů',
#         '19.1 Výroba koksárenských produktů',
#         '19.10 Výroba koksárenských produktů',
#         '19.2 Výroba rafinovaných ropných produktů',
#         '19.20 Výroba rafinovaných ropných produktů',
#         '20.1 Výroba základních chemických látek, hnojiv a\xa0dusíkatých sloučenin, plastů a syntetického kaučuku v primárních formách',
#         '20.11 Výroba technických plynů', '20.12 Výroba barviv a pigmentů',
#         '20.13 Výroba jiných základních anorganických chemických látek',
#         '20.14.1 Výroba bioetanolu (biolihu) pro pohon motorů a pro výrobu směsí a\xa0komponent paliv pro pohon motorů',
#         '20.14.9 Výroba ostatních základních organických chemických látek',
#         '20.14 Výroba jiných základních organických chemických látek',
#         '20.15 Výroba hnojiv a dusíkatých sloučenin',
#         '20.16 Výroba plastů v primárních formách',
#         '20.17 Výroba syntetického kaučuku v primárních formách',
#         '20.2 Výroba pesticidů a jiných agrochemických přípravků',
#         '20.20 Výroba pesticidů a jiných agrochemických přípravků',
#         '20.3 Výroba nátěrových barev, laků a jiných nátěrových materiálů, tiskařských barev a tmelů',
#         '20.30 Výroba nátěrových barev, laků a jiných nátěrových materiálů, tiskařských barev a tmelů',
#         '20.4 Výroba mýdel a detergentů, čisticích a lešticích prostředků, parfémů a\xa0toaletních přípravků',
#         '20.41 Výroba mýdel a detergentů, čisticích a lešticích prostředků',
#         '20.42 Výroba parfémů a toaletních přípravků',
#         '20.5 Výroba ostatních chemických výrobků',
#         '20.51 Výroba výbušnin', '20.52 Výroba klihů',
#         '20.53 Výroba vonných silic',
#         '20.59.1 Výroba metylesterů a etylesterů mastných kyselin pro pohon motorů a\xa0pro\xa0výrobu směsí paliv pro pohon motorů',
#         '20.59.9 Výroba jiných chemických výrobků j. n.',
#         '20.59 Výroba ostatních chemických výrobků j. n.',
#         '20.6 Výroba chemických vláken', '20.60 Výroba chemických vláken',
#         '21.1 Výroba základních farmaceutických výrobků',
#         '21.10 Výroba základních farmaceutických výrobků',
#         '21.2 Výroba farmaceutických přípravků',
#         '21.20 Výroba farmaceutických přípravků',
#         '22.1 Výroba pryžových výrobků',
#         '22.11 Výroba pryžových plášťů a duší; protektorování pneumatik',
#         '22.19 Výroba ostatních pryžových výrobků',
#         '22.2 Výroba plastových výrobků',
#         '22.21 Výroba plastových desek, fólií, hadic, trubek a profilů',
#         '22.22 Výroba plastových obalů',
#         '22.23 Výroba plastových výrobků pro stavebnictví',
#         '22.29 Výroba ostatních plastových výrobků',
#         '23.1 Výroba skla a skleněných výrobků',
#         '23.11 Výroba plochého skla',
#         '23.12 Tvarování a zpracování plochého skla',
#         '23.13 Výroba dutého skla', '23.14 Výroba skleněných vláken',
#         '23.19 Výroba a zpracování ostatního skla vč. technického',
#         '23.2 Výroba žáruvzdorných výrobků',
#         '23.20 Výroba žáruvzdorných výrobků',
#         '23.3 Výroba stavebních výrobků z jílovitých materiálů',
#         '23.31 Výroba keramických obkládaček a dlaždic',
#         '23.32 Výroba pálených zdicích materiálů, tašek, dlaždic a\xa0podobných výrobků',
#         '23.4 Výroba ostatních porcelánových a keramických výrobků',
#         '23.41 Výroba keramických a porcelánových výrobků převážně pro domácnost a\xa0ozdobných předmětů',
#         '23.42 Výroba keramických sanitárních výrobků',
#         '23.43 Výroba keramických izolátorů a izolačního příslušenství',
#         '23.44 Výroba ostatních technických keramických výrobků',
#         '23.49 Výroba ostatních keramických výrobků',
#         '23.5 Výroba cementu, vápna a sádry', '23.51 Výroba cementu',
#         '23.52 Výroba vápna a sádry',
#         '23.6 Výroba betonových, cementových a sádrových výrobků',
#         '23.61 Výroba betonových výrobků pro stavební účely',
#         '23.62 Výroba sádrových výrobků pro stavební účely',
#         '23.63 Výroba betonu připraveného k lití', '23.64 Výroba malt',
#         '23.65 Výroba vláknitých cementů',
#         '23.69 Výroba ostatních betonových, cementových a\xa0sádrových výrobků',
#         '23.7 Řezání, tvarování a konečná úprava kamenů',
#         '23.70 Řezání, tvarování a konečná úprava kamenů',
#         '23.9 Výroba brusiv a ostatních nekovových minerálních výrobků j. n.',
#         '23.91 Výroba brusiv',
#         '23.99 Výroba ostatních nekovových minerálních výrobků j.\xa0n.',
#         '24.1 Výroba surového železa, oceli a feroslitin, plochých výrobků (kromě pásky za studena), tváření výrobků za tepla',
#         '24.10.1 Výroba surového železa, oceli a feroslitin',
#         '24.10.2 Výroba plochých výrobků (kromě pásky za studena)',
#         '24.10.3 Tváření výrobků za tepla',
#         '24.10 Výroba surového železa, oceli a feroslitin, plochých výrobků (kromě pásky za studena), tváření výrobků za tepla',
#         '24.2 Výroba ocelových trub, trubek, dutých profilů a\xa0souvisejících potrubních tvarovek',
#         '24.20 Výroba ocelových trub, trubek, dutých profilů a\xa0souvisejících potrubních tvarovek',
#         '24.3 Výroba ostatních výrobků získaných jednostupňovým zpracováním oceli',
#         '24.31 Tažení tyčí za studena',
#         '24.32 Válcování ocelových úzkých pásů za studena',
#         '24.33 Tváření ocelových profilů za studena',
#         '24.34 Tažení ocelového drátu za studena',
#         '24.4 Výroba a hutní zpracování drahých a neželezných kovů',
#         '24.41 Výroba a hutní zpracování drahých kovů',
#         '24.42 Výroba a hutní zpracování hliníku',
#         '24.43 Výroba a hutní zpracování olova, zinku a cínu',
#         '24.44 Výroba a hutní zpracování mědi',
#         '24.45 Výroba a hutní zpracování ostatních neželezných kovů',
#         '24.46 Zpracování jaderného paliva', '24.5 Slévárenství',
#         '24.51.1 Výroba odlitků z litiny s lupínkovým grafitem',
#         '24.51.2 Výroba odlitků z litiny s kuličkovým grafitem',
#         '24.51.9 Výroba ostatních odlitků z litiny',
#         '24.51 Výroba odlitků z litiny',
#         '24.52.1 Výroba odlitků z uhlíkatých ocelí',
#         '24.52.2 Výroba odlitků z legovaných ocelí',
#         '24.52 Výroba odlitků z oceli',
#         '24.53 Výroba odlitků z lehkých neželezných kovů',
#         '24.54 Výroba odlitků z ostatních neželezných kovů',
#         '25.1 Výroba konstrukčních kovových výrobků',
#         '25.11 Výroba kovových konstrukcí a jejich dílů',
#         '25.12 Výroba kovových dveří a oken',
#         '25.2 Výroba radiátorů a kotlů k ústřednímu topení, kovových nádrží a zásobníků',
#         '25.21 Výroba radiátorů a kotlů k ústřednímu topení',
#         '25.29 Výroba kovových nádrží a zásobníků',
#         '25.3 Výroba parních kotlů, kromě kotlů pro ústřední topení',
#         '25.30 Výroba parních kotlů, kromě kotlů pro ústřední topení',
#         '25.4 Výroba zbraní a střeliva', '25.40 Výroba zbraní a střeliva',
#         '25.5 Kování, lisování, ražení, válcování a protlačování kovů; prášková metalurgie',
#         '25.50 Kování, lisování, ražení, válcování a protlačování kovů; prášková metalurgie',
#         '25.6 Povrchová úprava a zušlechťování kovů; obrábění',
#         '25.61 Povrchová úprava a zušlechťování kovů', '25.62 Obrábění',
#         '25.7 Výroba nožířských výrobků, nástrojů a\xa0železářských výrobků',
#         '25.71 Výroba nožířských výrobků', '25.72 Výroba zámků a kování',
#         '25.73 Výroba nástrojů a nářadí',
#         '25.9 Výroba ostatních kovodělných výrobků',
#         '25.91 Výroba ocelových sudů a podobných nádob',
#         '25.92 Výroba drobných kovových obalů',
#         '25.93 Výroba drátěných výrobků, řetězů a pružin',
#         '25.94 Výroba spojovacích materiálů a spojovacích výrobků se\xa0závity',
#         '25.99 Výroba ostatních kovodělných výrobků j. n.',
#         '26.1 Výroba elektronických součástek a desek',
#         '26.11 Výroba elektronických součástek',
#         '26.12 Výroba osazených elektronických desek',
#         '26.2 Výroba počítačů a periferních zařízení',
#         '26.20 Výroba počítačů a periferních zařízení',
#         '26.3 Výroba komunikačních zařízení',
#         '26.30 Výroba komunikačních zařízení',
#         '26.4 Výroba spotřební elektroniky',
#         '26.40 Výroba spotřební elektroniky',
#         '26.5 Výroba měřicích, zkušebních a navigačních přístrojů; výroba časoměrných přístrojů',
#         '26.51 Výroba měřicích, zkušebních a navigačních přístrojů',
#         '26.52 Výroba časoměrných přístrojů',
#         '26.6 Výroba ozařovacích, elektroléčebných a\xa0elektroterapeutických přístrojů',
#         '26.60 Výroba ozařovacích, elektroléčebných a\xa0elektroterapeutických přístrojů',
#         '26.7 Výroba optických a fotografických přístrojů a zařízení',
#         '26.70 Výroba optických a fotografických přístrojů a zařízení',
#         '26.8 Výroba magnetických a optických médií',
#         '26.80 Výroba magnetických a optických médií',
#         '27.1 Výroba elektrických motorů, generátorů, transformátorů a\xa0elektrických rozvodných a kontrolních zařízení',
#         '27.11 Výroba elektrických motorů, generátorů a\xa0transformátorů',
#         '27.12 Výroba elektrických rozvodných a kontrolních zařízení',
#         '27.2 Výroba baterií a akumulátorů',
#         '27.20 Výroba baterií a akumulátorů',
#         '27.3 Výroba optických a elektrických kabelů, elektrických vodičů a elektroinstalačních zařízení',
#         '27.31 Výroba optických kabelů',
#         '27.32 Výroba elektrických vodičů a kabelů j. n.',
#         '27.33 Výroba elektroinstalačních zařízení',
#         '27.4 Výroba elektrických osvětlovacích zařízení',
#         '27.40 Výroba elektrických osvětlovacích zařízení',
#         '27.5 Výroba spotřebičů převážně pro domácnost',
#         '27.51 Výroba elektrických spotřebičů převážně pro\xa0domácnost',
#         '27.52 Výroba neelektrických spotřebičů převážně pro\xa0domácnost',
#         '27.9 Výroba ostatních elektrických zařízení',
#         '27.90 Výroba ostatních elektrických zařízení',
#         '28.1 Výroba strojů a zařízení pro všeobecné účely',
#         '28.11 Výroba motorů a turbín, kromě motorů pro letadla, automobily a\xa0motocykly',
#         '28.12 Výroba hydraulických a pneumatických zařízení',
#         '28.13 Výroba ostatních čerpadel a kompresorů',
#         '28.14 Výroba ostatních potrubních armatur',
#         '28.15 Výroba ložisek, ozubených kol, převodů a hnacích prvků',
#         '28.2 Výroba ostatních strojů a zařízení pro všeobecné účely',
#         '28.21 Výroba pecí a hořáků pro topeniště',
#         '28.22 Výroba zdvihacích a manipulačních zařízení',
#         '28.23 Výroba kancelářských strojů a zařízení, kromě počítačů a periferních zařízení',
#         '28.24 Výroba ručních mechanizovaných nástrojů',
#         '28.25 Výroba průmyslových chladicích a klimatizačních zařízení',
#         '28.29 Výroba ostatních strojů a zařízení pro všeobecné účely j. n.',
#         '28.3 Výroba zemědělských a lesnických strojů',
#         '28.30 Výroba zemědělských a lesnických strojů',
#         '28.4 Výroba kovoobráběcích a ostatních obráběcích strojů',
#         '28.41 Výroba kovoobráběcích strojů',
#         '28.49 Výroba ostatních obráběcích strojů',
#         '28.9 Výroba ostatních strojů pro speciální účely',
#         '28.91 Výroba strojů pro metalurgii',
#         '28.92 Výroba strojů pro těžbu, dobývání a stavebnictví',
#         '28.93 Výroba strojů na výrobu potravin, nápojů a\xa0zpracování tabáku',
#         '28.94 Výroba strojů na výrobu textilu, oděvních výrobků a\xa0výrobků z usní',
#         '28.95 Výroba strojů a přístrojů na výrobu papíru a lepenky',
#         '28.96 Výroba strojů na výrobu plastů a pryže',
#         '28.99 Výroba ostatních strojů pro speciální účely j. n.',
#         '29.1 Výroba motorových vozidel a jejich motorů',
#         '29.10 Výroba motorových vozidel a jejich motorů',
#         '29.2 Výroba karoserií motorových vozidel; výroba přívěsů a návěsů',
#         '29.20 Výroba karoserií motorových vozidel; výroba přívěsů a\xa0návěsů',
#         '29.3 Výroba dílů a příslušenství pro motorová vozidla a jejich motory',
#         '29.31 Výroba elektrického a elektronického zařízení pro\xa0motorová vozidla',
#         '29.32 Výroba ostatních dílů a příslušenství pro motorová vozidla',
#         '30.1 Stavba lodí a člunů', '30.11 Stavba lodí a plavidel',
#         '30.12 Stavba rekreačních a sportovních člunů',
#         '30.2 Výroba železničních lokomotiv a vozového parku',
#         '30.20 Výroba železničních lokomotiv a vozového parku',
#         '30.3 Výroba letadel a jejich motorů, kosmických lodí a souvisejících zařízení',
#         '30.30 Výroba letadel a jejich motorů, kosmických lodí a souvisejících zařízení',
#         '30.4 Výroba vojenských bojových vozidel',
#         '30.40 Výroba vojenských bojových vozidel',
#         '30.9 Výroba dopravních prostředků a zařízení j. n.',
#         '30.91 Výroba motocyklů',
#         '30.92 Výroba jízdních kol a vozíků pro invalidy',
#         '30.99 Výroba ostatních dopravních prostředků a zařízení j. n.',
#         '31.0 Výroba nábytku',
#         '31.01 Výroba kancelářského nábytku a zařízení obchodů',
#         '31.02 Výroba kuchyňského nábytku', '31.03 Výroba matrací',
#         '31.09 Výroba ostatního nábytku',
#         '32.1 Výroba klenotů, bižuterie a\xa0příbuzných výrobků',
#         '32.11 Ražení mincí', '32.12 Výroba klenotů a příbuzných výrobků',
#         '32.13 Výroba bižuterie a příbuzných výrobků',
#         '32.2 Výroba hudebních nástrojů',
#         '32.20 Výroba hudebních nástrojů',
#         '32.3 Výroba sportovních potřeb',
#         '32.30 Výroba sportovních potřeb', '32.4 Výroba her a hraček',
#         '32.40 Výroba her a hraček',
#         '32.5 Výroba lékařských a dentálních nástrojů a potřeb',
#         '32.50 Výroba lékařských a dentálních nástrojů a potřeb',
#         '32.9 Zpracovatelský průmysl j. n.',
#         '32.91 Výroba košťat a kartáčnických výrobků',
#         '32.99 Ostatní zpracovatelský průmysl j. n.',
#         '33.1 Opravy kovodělných výrobků, strojů a zařízení',
#         '33.11 Opravy kovodělných výrobků', '33.12 Opravy strojů',
#         '33.13 Opravy elektronických a optických přístrojů a zařízení',
#         '33.14 Opravy elektrických zařízení',
#         '33.15 Opravy a údržba lodí a člunů',
#         '33.16 Opravy a údržba letadel a kosmických lodí',
#         '33.17.1 Opravy a údržba kolejových vozidel',
#         '33.17.9 Opravy a údržba ostatních dopravních prostředků a zařízení j. n. kromě kolejových vozidel',
#         '33.17 Opravy a údržba ostatních dopravních prostředků a zařízení j. n.',
#         '33.19 Opravy ostatních zařízení',
#         '33.2 Instalace průmyslových strojů a zařízení',
#         '33.20 Instalace průmyslových strojů a zařízení'], dtype=object),
#  'SEKCE D – VÝROBA A ROZVOD ELEKTŘINY, PLYNU, TEPLA A\xa0KLIMATIZOVANÉHO VZDUCHU': array(['35.1 Výroba, přenos a rozvod elektřiny', '35.11 Výroba elektřiny',
#         '35.12 Přenos elektřiny', '35.13 Rozvod elektřiny',
#         '35.14 Obchod s elektřinou',
#         '35.2 Výroba plynu; rozvod plynných paliv prostřednictvím sítí',
#         '35.21 Výroba plynu',
#         '35.22 Rozvod plynných paliv prostřednictvím sítí',
#         '35.23 Obchod s\xa0plynem prostřednictvím sítí',
#         '35.3 Výroba a rozvod tepla a klimatizovaného vzduchu, výroba ledu',
#         '35.30.1 Výroba tepla', '35.30.2 Rozvod tepla',
#         '35.30.3 Výroba klimatizovaného vzduchu',
#         '35.30.4 Rozvod klimatizovaného vzduchu',
#         '35.30.5 Výroba chladicí vody', '35.30.6 Rozvod chladicí vody',
#         '35.30.7 Výroba ledu',
#         '35.30 Výroba a rozvod tepla a klimatizovaného vzduchu, výroba ledu'],
#        dtype=object),
#  'SEKCE E – ZÁSOBOVÁNÍ VODOU; ČINNOSTI SOUVISEJÍCÍ S\xa0ODPADNÍMI VODAMI, ODPADY A SANACEMI': array(['36.0 Shromažďování, úprava a rozvod vody',
#         '36.00 Shromažďování, úprava a rozvod vody',
#         '37.0 Činnosti související s\xa0odpadními vodami',
#         '37.00 Činnosti související s\xa0odpadními vodami',
#         '38.1 Shromažďování a sběr odpadů',
#         '38.11 Shromažďování a sběr odpadů, kromě nebezpečných',
#         '38.12 Shromažďování a sběr nebezpečných odpadů',
#         '38.2 Odstraňování odpadů',
#         '38.21 Odstraňování odpadů, kromě nebezpečných',
#         '38.22 Odstraňování nebezpečných odpadů',
#         '38.3 Úprava odpadů k dalšímu využití',
#         '38.31 Demontáž vraků a vyřazených strojů a zařízení pro účely recyklace',
#         '38.32 Úprava odpadů k dalšímu využití, kromě demontáže vraků, strojů a zařízení',
#         '39.0 Sanace a jiné činnosti související s odpady',
#         '39.00 Sanace a jiné činnosti související s odpady'], dtype=object),
#  'SEKCE F - STAVEBNICTVÍ': array(['41.1 Developerská činnost', '41.10 Developerská činnost',
#         '41.2 Výstavba bytových a nebytových budov',
#         '41.20.1 Výstavba bytových budov',
#         '41.20.2 Výstavba nebytových budov',
#         '41.20 Výstavba bytových a nebytových budov',
#         '42.1 Výstavba silnic a železnic',
#         '42.11 Výstavba silnic a dálnic',
#         '42.12 Výstavba železnic a podzemních drah',
#         '42.13 Výstavba mostů a tunelů', '42.2 Výstavba inženýrských sítí',
#         '42.21.1 Výstavba inženýrských sítí pro kapaliny',
#         '42.21.2 Výstavba inženýrských sítí pro plyny',
#         '42.21 Výstavba inženýrských sítí pro kapaliny a plyny',
#         '42.22 Výstavba inženýrských sítí pro elektřinu a\xa0telekomunikace',
#         '42.9 Výstavba ostatních staveb', '42.91 Výstavba vodních děl',
#         '42.99 Výstavba ostatních staveb j. n.',
#         '43.1 Demolice a příprava staveniště', '43.11 Demolice',
#         '43.12 Příprava staveniště', '43.13 Průzkumné vrtné práce',
#         '43.2 Elektroinstalační, instalatérské a ostatní stavebně instalační práce',
#         '43.21 Elektrické instalace',
#         '43.22 Instalace vody, odpadu, plynu, topení a klimatizace',
#         '43.29 Ostatní stavební instalace',
#         '43.3 Kompletační a dokončovací práce', '43.31 Omítkářské práce',
#         '43.32 Truhlářské práce',
#         '43.33 Obkládání stěn a pokládání podlahových krytin',
#         '43.34.1 Sklenářské práce', '43.34.2 Malířské a natěračské práce',
#         '43.34 Sklenářské, malířské a natěračské práce',
#         '43.39 Ostatní kompletační a dokončovací práce',
#         '43.9 Ostatní specializované stavební činnosti',
#         '43.91 Pokrývačské práce',
#         '43.99.1 Montáž a demontáž lešení a bednění',
#         '43.99.9 Jiné specializované stavební činnosti j. n.',
#         '43.99 Ostatní specializované stavební činnosti j. n.'],
#        dtype=object),
#  'SEKCE G - VELKOOBCHOD A MALOOBCHOD; OPRAVY A\xa0ÚDRŽBA MOTOROVÝCH VOZIDEL': array(['45.1 Obchod s motorovými vozidly, kromě motocyklů',
#         '45.11 Obchod s\xa0automobily a jinými lehkými motorovými vozidly',
#         '45.19 Obchod s\xa0ostatními motorovými vozidly, kromě motocyklů',
#         '45.2 Opravy a údržba motorových vozidel, kromě motocyklů',
#         '45.20 Opravy a údržba motorových vozidel, kromě motocyklů',
#         '45.3 Obchod s díly a příslušenstvím pro motorová vozidla, kromě motocyklů',
#         '45.31 Velkoobchod s díly a příslušenstvím pro motorová vozidla, kromě motocyklů',
#         '45.32 Maloobchod s díly a příslušenstvím pro motorová vozidla, kromě motocyklů',
#         '45.4 Obchod, opravy a údržba motocyklů, jejich dílů a\xa0příslušenství',
#         '45.40 Obchod, opravy a údržba motocyklů, jejich dílů a\xa0příslušenství',
#         '46.1 Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení',
#         '46.11 Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení se základními zemědělskými produkty, živými zvířaty, textilními surovinami a polotovary',
#         '46.12 Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s\xa0palivy, rudami, kovy a průmyslovými chemikáliemi',
#         '46.13 Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení se dřevem a stavebními materiály',
#         '46.14 Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení se stroji, průmyslovým zařízením, loděmi a letadly',
#         '46.15 Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s\xa0nábytkem, železářským zbožím a\xa0potřebami převážně pro\xa0domácnost',
#         '46.16 Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s\xa0textilem, oděvy, kožešinami, obuví a\xa0koženými výrobky',
#         '46.17 Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s potravinami, nápoji, tabákem a\xa0tabákovými výrobky',
#         '46.18.1 Zprostředkování velkoobchodu a velkoobchod v\xa0zastoupení s\xa0papírenskými výrobky',
#         '46.18.9 Zprostředkování specializovaného velkoobchodu a velkoobchod v\xa0zastoupení s\xa0ostatními výrobky j. n.',
#         '46.18 Zprostředkování specializovaného velkoobchodu a specializovaný velkoobchod v\xa0zastoupení s\xa0ostatními výrobky',
#         '46.19 Zprostředkování nespecializovaného velkoobchodu a nespecializovaný velkoobchod v\xa0zastoupení',
#         '46.2 Velkoobchod se základními zemědělskými produkty a živými zvířaty',
#         '46.21 Velkoobchod s\xa0obilím, surovým tabákem, osivy a\xa0krmivy',
#         '46.22 Velkoobchod s\xa0květinami a jinými rostlinami',
#         '46.23 Velkoobchod s živými zvířaty',
#         '46.24 Velkoobchod se surovými kůžemi, kožešinami a\xa0usněmi',
#         '46.3 Velkoobchod s\xa0potravinami, nápoji a tabákovými výrobky',
#         '46.31 Velkoobchod s\xa0ovocem a zeleninou',
#         '46.32 Velkoobchod s\xa0masem a masnými výrobky',
#         '46.33 Velkoobchod s mléčnými výrobky, vejci, jedlými oleji a tuky',
#         '46.34 Velkoobchod s nápoji',
#         '46.35 Velkoobchod s\xa0tabákovými výrobky',
#         '46.36 Velkoobchod s\xa0cukrem, čokoládou a cukrovinkami',
#         '46.37 Velkoobchod s\xa0kávou, čajem, kakaem a kořením',
#         '46.38 Specializovaný velkoobchod s\xa0jinými potravinami, včetně\xa0ryb, korýšů a\xa0měkkýšů',
#         '46.39 Nespecializovaný velkoobchod s\xa0potravinami, nápoji a\xa0tabákovými výrobky',
#         '46.4 Velkoobchod s\xa0výrobky převážně pro domácnost',
#         '46.41 Velkoobchod s\xa0textilem', '46.42.1 Velkoobchod s oděvy',
#         '46.42.2 Velkoobchod s obuví',
#         '46.42 Velkoobchod s\xa0oděvy a obuví',
#         '46.43 Velkoobchod s\xa0elektrospotřebiči a elektronikou',
#         '46.44.1 Velkoobchod s\xa0porcelánovými, keramickými a skleněnými výrobky',
#         '46.44.2 Velkoobchod s\xa0pracími a čisticími prostředky',
#         '46.44 Velkoobchod s\xa0porcelánovými, keramickými a skleněnými výrobky a\xa0čisticími prostředky',
#         '46.45 Velkoobchod s\xa0kosmetickými výrobky',
#         '46.46 Velkoobchod s\xa0farmaceutickými výrobky',
#         '46.47 Velkoobchod s\xa0nábytkem, koberci a svítidly',
#         '46.48 Velkoobchod s\xa0hodinami, hodinkami a klenoty',
#         '46.49 Velkoobchod s\xa0ostatními výrobky převážně pro\xa0domácnost',
#         '46.5 Velkoobchod s\xa0počítačovým a komunikačním zařízením',
#         '46.51 Velkoobchod s\xa0počítači, počítačovým periferním zařízením a softwarem',
#         '46.52 Velkoobchod s\xa0elektronickým a telekomunikačním zařízením a jeho díly',
#         '46.6 Velkoobchod s ostatními stroji, strojním zařízením a příslušenstvím',
#         '46.61 Velkoobchod se zemědělskými stroji, strojním zařízením a příslušenstvím',
#         '46.62 Velkoobchod s\xa0obráběcími stroji',
#         '46.63 Velkoobchod s\xa0těžebními a stavebními stroji a\xa0zařízením',
#         '46.64 Velkoobchod se strojním zařízením pro textilní průmysl, šicími a pletacími stroji',
#         '46.65 Velkoobchod s\xa0kancelářským nábytkem',
#         '46.66 Velkoobchod s\xa0ostatními kancelářskými stroji a\xa0zařízením',
#         '46.69 Velkoobchod s\xa0ostatními stroji a zařízením',
#         '46.7 Ostatní specializovaný velkoobchod',
#         '46.71.1 Velkoobchod s pevnými palivy a příbuznými výrobky',
#         '46.71.2 Velkoobchod s kapalnými palivy a příbuznými výrobky',
#         '46.71.3 Velkoobchod s plynnými palivy a příbuznými výrobky',
#         '46.71 Velkoobchod s\xa0pevnými, kapalnými a plynnými palivy a příbuznými výrobky',
#         '46.72 Velkoobchod s\xa0rudami, kovy a hutními výrobky',
#         '46.73 Velkoobchod se dřevem, stavebními materiály a\xa0sanitárním vybavením',
#         '46.74 Velkoobchod s\xa0železářským zbožím, instalatérskými a\xa0topenářskými potřebami',
#         '46.75 Velkoobchod s\xa0chemickými výrobky',
#         '46.76.1 Velkoobchod s\xa0papírenskými meziprodukty',
#         '46.76.9 Velkoobchod s\xa0ostatními meziprodukty j. n.',
#         '46.76 Velkoobchod s\xa0ostatními meziprodukty',
#         '46.77 Velkoobchod s\xa0odpadem a šrotem',
#         '46.9 Nespecializovaný velkoobchod',
#         '46.90 Nespecializovaný velkoobchod',
#         '47.1 Maloobchod v\xa0nespecializovaných prodejnách',
#         '47.11 Maloobchod s\xa0převahou potravin, nápojů a tabákových výrobků v\xa0nespecializovaných prodejnách',
#         '47.19 Ostatní maloobchod v nespecializovaných prodejnách',
#         '47.2 Maloobchod s potravinami, nápoji a tabákovými výrobky ve\xa0specializovaných prodejnách',
#         '47.21 Maloobchod s\xa0ovocem a zeleninou',
#         '47.22 Maloobchod s\xa0masem a masnými výrobky',
#         '47.23 Maloobchod s\xa0rybami, korýši a měkkýši',
#         '47.24 Maloobchod s\xa0chlebem, pečivem, cukrářskými výrobky a cukrovinkami',
#         '47.25 Maloobchod s\xa0nápoji',
#         '47.26 Maloobchod s tabákovými výrobky',
#         '47.29 Ostatní maloobchod s\xa0potravinami ve specializovaných prodejnách',
#         '47.3 Maloobchod s pohonnými hmotami ve\xa0specializovaných prodejnách',
#         '47.30 Maloobchod s pohonnými hmotami ve\xa0specializovaných prodejnách',
#         '47.4 Maloobchod s\xa0počítačovým a komunikačním zařízením ve\xa0specializovaných prodejnách',
#         '47.41 Maloobchod s\xa0počítači, počítačovým periferním zařízením a softwarem',
#         '47.42 Maloobchod s telekomunikačním zařízením',
#         '47.43 Maloobchod s audio- a videozařízením',
#         '47.5 Maloobchod s\xa0ostatními výrobky převážně pro\xa0domácnost ve\xa0specializovaných prodejnách',
#         '47.51 Maloobchod s\xa0textilem',
#         '47.52 Maloobchod s\xa0železářským zbožím, barvami, sklem a\xa0potřebami pro kutily',
#         '47.53 Maloobchod s\xa0koberci, podlahovými krytinami a\xa0nástěnnými obklady',
#         '47.54 Maloobchod s\xa0elektrospotřebiči a elektronikou',
#         '47.59 Maloobchod s\xa0nábytkem, svítidly a ostatními výrobky převážně pro\xa0domácnost ve\xa0specializovaných prodejnách',
#         '47.6 Maloobchod s\xa0výrobky pro kulturní rozhled a\xa0rekreaci ve\xa0specializovaných prodejnách',
#         '47.61 Maloobchod s\xa0knihami',
#         '47.62 Maloobchod s novinami, časopisy a papírnickým zbožím',
#         '47.63 Maloobchod s\xa0audio- a\xa0videozáznamy',
#         '47.64 Maloobchod se sportovním vybavením',
#         '47.65 Maloobchod s\xa0hrami a hračkami',
#         '47.7 Maloobchod s\xa0ostatním zbožím ve specializovaných prodejnách',
#         '47.71 Maloobchod s\xa0oděvy',
#         '47.72 Maloobchod s\xa0obuví a koženými výrobky',
#         '47.73 Maloobchod s\xa0farmaceutickými přípravky',
#         '47.74 Maloobchod se zdravotnickými a ortopedickými výrobky',
#         '47.75 Maloobchod s\xa0kosmetickými a toaletními výrobky',
#         '47.76 Maloobchod s\xa0květinami, rostlinami, osivy, hnojivy, zvířaty pro\xa0zájmový chov a krmivy pro ně',
#         '47.77 Maloobchod s\xa0hodinami, hodinkami a klenoty',
#         '47.78.1 Maloobchod s\xa0fotografickým a optickým zařízením a potřebami',
#         '47.78.2 Maloobchod s\xa0pevnými palivy',
#         '47.78.3 Maloobchod s kapalnými palivy (kromě pohonných hmot)',
#         '47.78.4 Maloobchod s plynnými palivy (kromě pohonných hmot)',
#         '47.78.9 Ostatní maloobchod s\xa0novým zbožím ve\xa0specializovaných prodejnách j. n.',
#         '47.78 Ostatní maloobchod s\xa0novým zbožím ve\xa0specializovaných prodejnách',
#         '47.79 Maloobchod s použitým zbožím v prodejnách',
#         '47.8 Maloobchod ve stáncích a na trzích',
#         '47.81 Maloobchod s potravinami, nápoji a tabákovými výrobky ve stáncích a\xa0na\xa0trzích',
#         '47.82 Maloobchod s\xa0textilem, oděvy a obuví ve stáncích a\xa0na\xa0trzích',
#         '47.89 Maloobchod s\xa0ostatním zbožím ve stáncích a na trzích',
#         '47.9 Maloobchod mimo prodejny, stánky a trhy',
#         '47.91.1 Maloobchod prostřednictvím internetu',
#         '47.91.2 Maloobchod prostřednictvím zásilkové služby (jiný než prostřednictvím internetu)',
#         '47.91 Maloobchod prostřednictvím internetu nebo zásilkové služby',
#         '47.99 Ostatní maloobchod mimo prodejny, stánky a trhy'],
#        dtype=object),
#  'SEKCE H - DOPRAVA A SKLADOVÁNÍ': array(['49.1 Železniční osobní doprava meziměstská',
#         '49.10 Železniční osobní doprava meziměstská',
#         '49.2 Železniční nákladní doprava',
#         '49.20 Železniční nákladní doprava',
#         '49.3 Ostatní pozemní osobní doprava',
#         '49.31 Městská a příměstská pozemní osobní doprava',
#         '49.32 Taxislužba a pronájem osobních vozů s řidičem',
#         '49.39.1 Meziměstská pravidelná pozemní osobní doprava',
#         '49.39.2 Osobní doprava lanovkou nebo vlekem',
#         '49.39.3 Nepravidelná pozemní osobní doprava',
#         '49.39.9 Jiná pozemní osobní doprava j. n.',
#         '49.39 Ostatní pozemní osobní doprava j. n.',
#         '49.4 Silniční nákladní doprava a stěhovací služby',
#         '49.41 Silniční nákladní doprava', '49.42 Stěhovací služby',
#         '49.5 Potrubní doprava', '49.50.1 Potrubní doprava ropovodem',
#         '49.50.2 Potrubní doprava plynovodem',
#         '49.50.9 Potrubní doprava ostatní', '49.50 Potrubní doprava',
#         '50.1 Námořní a pobřežní osobní doprava',
#         '50.10 Námořní a pobřežní osobní doprava',
#         '50.2 Námořní a pobřežní nákladní doprava',
#         '50.20 Námořní a pobřežní nákladní doprava',
#         '50.3 Vnitrozemská vodní osobní doprava',
#         '50.30 Vnitrozemská vodní osobní doprava',
#         '50.4 Vnitrozemská vodní nákladní doprava',
#         '50.40 Vnitrozemská vodní nákladní doprava',
#         '51.1 Letecká osobní doprava',
#         '51.10.1 Vnitrostátní pravidelná letecká osobní doprava',
#         '51.10.2 Vnitrostátní nepravidelná letecká osobní doprava',
#         '51.10.3 Mezinárodní pravidelná letecká osobní doprava',
#         '51.10.4 Mezinárodní nepravidelná letecká osobní doprava',
#         '51.10.9 Ostatní letecká osobní doprava',
#         '51.10 Letecká osobní doprava',
#         '51.2 Letecká nákladní doprava a kosmická doprava',
#         '51.21 Letecká nákladní doprava', '51.22 Kosmická doprava',
#         '52.1 Skladování', '52.10 Skladování',
#         '52.2 Vedlejší činnosti v dopravě',
#         '52.21 Činnosti související s\xa0pozemní dopravou',
#         '52.22 Činnosti související s\xa0vodní dopravou',
#         '52.23 Činnosti související s\xa0leteckou dopravou',
#         '52.24 Manipulace s\xa0nákladem',
#         '52.29 Ostatní vedlejší činnosti v\xa0dopravě',
#         '53.1 Základní poštovní služby poskytované na základě poštovní licence',
#         '53.10 Základní poštovní služby poskytované na základě poštovní licence',
#         '53.2 Ostatní poštovní a kurýrní činnosti',
#         '53.20 Ostatní poštovní a kurýrní činnosti'], dtype=object),
#  'SEKCE I - UBYTOVÁNÍ, STRAVOVÁNÍ A\xa0POHOSTINSTVÍ': array(['55.1 Ubytování v hotelích a podobných ubytovacích zařízeních',
#         '55.10.1 Hotely', '55.10.2 Motely, botely',
#         '55.10.9 Ostatní podobná ubytovací zařízení',
#         '55.10 Ubytování v hotelích a podobných ubytovacích zařízeních',
#         '55.2 Rekreační a ostatní krátkodobé ubytování',
#         '55.20 Rekreační a ostatní krátkodobé ubytování',
#         '55.3 Kempy a tábořiště', '55.30 Kempy a tábořiště',
#         '55.9 Ostatní ubytování',
#         '55.90.1 Ubytování v\xa0zařízených pronájmech',
#         '55.90.2 Ubytování ve vysokoškolských kolejích, domovech mládeže',
#         '55.90.9 Ostatní ubytování j. n.', '55.90 Ostatní ubytování',
#         '56.1 Stravování v\xa0restauracích, u stánků a v mobilních zařízeních',
#         '56.10 Stravování v\xa0restauracích, u stánků a v mobilních zařízeních',
#         '56.2 Poskytování cateringových a ostatních stravovacích služeb',
#         '56.21 Poskytování cateringových služeb',
#         '56.29.1 Stravování v\xa0závodních kuchyních',
#         '56.29.2 Stravování ve školních zařízeních, menzách',
#         '56.29.9 Poskytování jiných stravovacích služeb j. n.',
#         '56.29 Poskytování ostatních stravovacích služeb',
#         '56.3 Pohostinství', '56.30 Pohostinství'], dtype=object),
#  'SEKCE J - INFORMAČNÍ A KOMUNIKAČNÍ ČINNOSTI': array(['58.1 Vydávání knih, periodických publikací a ostatní vydavatelské činnosti',
#         '58.11 Vydávání knih', '58.12 Vydávání adresářů a jiných seznamů',
#         '58.13 Vydávání novin',
#         '58.14 Vydávání časopisů a ostatních periodických publikací',
#         '58.19 Ostatní vydavatelské činnosti', '58.2 Vydávání softwaru',
#         '58.21 Vydávání počítačových her',
#         '58.29 Ostatní vydávání softwaru',
#         '59.1 Činnosti v\xa0oblasti filmů, videozáznamů a televizních programů',
#         '59.11 Produkce filmů, videozáznamů a televizních programů',
#         '59.12 Postprodukce filmů, videozáznamů a televizních programů',
#         '59.13 Distribuce filmů, videozáznamů a televizních programů',
#         '59.14 Promítání filmů',
#         '59.2 Pořizování zvukových nahrávek a hudební vydavatelské činnosti',
#         '59.20 Pořizování zvukových nahrávek a hudební vydavatelské činnosti',
#         '60.1 Rozhlasové vysílání', '60.10 Rozhlasové vysílání',
#         '60.2 Tvorba televizních programů a televizní vysílání',
#         '60.20 Tvorba televizních programů a televizní vysílání',
#         '61.1 Činnosti související s\xa0pevnou telekomunikační sítí',
#         '61.10.1 Poskytování hlasových služeb přes pevnou telekomunikační síť',
#         '61.10.2 Pronájem pevné telekomunikační sítě',
#         '61.10.3 Přenos dat přes pevnou telekomunikační síť',
#         '61.10.4 Poskytování přístupu k\xa0internetu přes pevnou telekomunikační síť',
#         '61.10.9 Ostatní činnosti související s\xa0pevnou telekomunikační sítí',
#         '61.10 Činnosti související s\xa0pevnou telekomunikační sítí',
#         '61.2 Činnosti související s bezdrátovou telekomunikační sítí',
#         '61.20.1 Poskytování hlasových služeb přes bezdrátovou telekomunikační síť',
#         '61.20.2 Pronájem bezdrátové telekomunikační sítě',
#         '61.20.3 Přenos dat přes bezdrátovou telekomunikační síť',
#         '61.20.4 Poskytování přístupu k\xa0internetu přes bezdrátovou telekomunikační síť',
#         '61.20.9 Ostatní činnosti související s\xa0bezdrátovou telekomunikační sítí',
#         '61.20 Činnosti související s bezdrátovou telekomunikační sítí',
#         '61.3 Činnosti související se satelitní telekomunikační sítí',
#         '61.30 Činnosti související se satelitní telekomunikační sítí',
#         '61.9 Ostatní telekomunikační činnosti',
#         '61.90 Ostatní telekomunikační činnosti',
#         '62.0 Činnosti v oblasti informačních technologií',
#         '62.01 Programování',
#         '62.02 Poradenství v\xa0oblasti informačních technologií',
#         '62.03 Správa počítačového vybavení',
#         '62.09 Ostatní činnosti v\xa0oblasti informačních technologií',
#         '63.1 Činnosti související se zpracováním dat a hostingem; činnosti související s webovými portály',
#         '63.11 Činnosti související se zpracováním dat a hostingem',
#         '63.12 Činnosti související s webovými portály',
#         '63.9 Ostatní informační činnosti',
#         '63.91 Činnosti zpravodajských tiskových kanceláří a agentur',
#         '63.99 Ostatní informační činnosti j. n.'], dtype=object),
#  'SEKCE K - PENĚŽNICTVÍ A POJIŠŤOVNICTVÍ': array(['64.1 Peněžní zprostředkování', '64.11 Centrální bankovnictví',
#         '64.19 Ostatní peněžní zprostředkování',
#         '64.2 Činnosti holdingových společností',
#         '64.20 Činnosti holdingových společností',
#         '64.3 Činnosti trustů, fondů a podobných finančních subjektů',
#         '64.30 Činnosti trustů, fondů a podobných finančních subjektů',
#         '64.9 Ostatní finanční zprostředkování', '64.91 Finanční leasing',
#         '64.92.1 Poskytování úvěrů společnostmi, které nepřijímají vklady',
#         '64.92.2 Poskytování obchodních úvěrů',
#         '64.92.3 Činnosti zastaváren',
#         '64.92.9 Ostatní poskytování úvěrů j. n.',
#         '64.92 Ostatní poskytování úvěrů', '64.99.1 Faktoringové činnosti',
#         '64.99.2 Obchodování s\xa0cennými papíry na vlastní účet',
#         '64.99.9 Jiné finanční zprostředkování j. n.',
#         '64.99 Ostatní finanční zprostředkování j. n.', '65.1 Pojištění',
#         '65.11 Životní pojištění', '65.12 Neživotní pojištění',
#         '65.2 Zajištění', '65.20 Zajištění', '65.3 Penzijní financování',
#         '65.30 Penzijní financování',
#         '66.1 Pomocné činnosti související s\xa0finančním zprostředkováním, kromě pojišťovnictví a\xa0penzijního financování',
#         '66.11 Řízení a správa finančních trhů',
#         '66.12 Obchodování s\xa0cennými papíry a komoditami na\xa0burzách',
#         '66.19 Ostatní pomocné činnosti související s finančním zprostředkováním',
#         '66.2 Pomocné činnosti související s\xa0pojišťovnictvím a\xa0penzijním financováním',
#         '66.21 Vyhodnocování rizik a škod',
#         '66.22 Činnosti zástupců pojišťovny a makléřů',
#         '66.29 Ostatní pomocné činnosti související s\xa0pojišťovnictvím a penzijním financováním',
#         '66.3 Správa fondů', '66.30 Správa fondů'], dtype=object),
#  'SEKCE L - ČINNOSTI V\xa0OBLASTI NEMOVITOSTÍ': array(['68.1 Nákup a následný prodej vlastních nemovitostí',
#         '68.10 Nákup a následný prodej vlastních nemovitostí',
#         '68.2 Pronájem a správa vlastních nebo\xa0pronajatých nemovitostí',
#         '68.20.1 Pronájem vlastních nebo pronajatých nemovitostí s\xa0bytovými prostory',
#         '68.20.2 Pronájem vlastních nebo pronajatých nemovitostí s\xa0nebytovými prostory',
#         '68.20.3 Správa vlastních nebo pronajatých nemovitostí s\xa0bytovými prostory',
#         '68.20.4 Správa vlastních nebo pronajatých nemovitostí s\xa0nebytovými prostory',
#         '68.20 Pronájem a správa vlastních nebo pronajatých nemovitostí',
#         '68.3 Činnosti v\xa0oblasti nemovitostí na základě smlouvy nebo dohody',
#         '68.31 Zprostředkovatelské činnosti realitních agentur',
#         '68.32 Správa nemovitostí na základě smlouvy'], dtype=object),
#  'SEKCE M - PROFESNÍ, VĚDECKÉ A\xa0TECHNICKÉ ČINNOSTI': array(['69.1 Právní činnosti', '69.10 Právní činnosti',
#         '69.2 Účetnické a auditorské činnosti; daňové poradenství',
#         '69.20 Účetnické a auditorské činnosti; daňové poradenství',
#         '70.1 Činnosti vedení podniků', '70.10 Činnosti vedení podniků',
#         '70.2 Poradenství v\xa0oblasti řízení',
#         '70.21 Poradenství v\xa0oblasti vztahů s\xa0veřejností a komunikace',
#         '70.22 Ostatní poradenství v\xa0oblasti podnikání a řízení',
#         '71.1 Architektonické a inženýrské činnosti a související technické poradenství',
#         '71.11 Architektonické činnosti', '71.12.1 Geologický průzkum',
#         '71.12.2 Zeměměřické a kartografické činnosti',
#         '71.12.3 Hydrometeorologické a meteorologické činnosti',
#         '71.12.9 Ostatní inženýrské činnosti a související technické poradenství j. n.',
#         '71.12 Inženýrské činnosti a související technické poradenství',
#         '71.2 Technické zkoušky a analýzy',
#         '71.20.1 Zkoušky a analýzy vyhrazených technických zařízení',
#         '71.20.9 Ostatní technické zkoušky a analýzy',
#         '71.20 Technické zkoušky a analýzy',
#         '72.1 Výzkum a vývoj v\xa0oblasti přírodních a technických věd',
#         '72.11 Výzkum a vývoj v\xa0oblasti biotechnologie',
#         '72.19.1 Výzkum a vývoj v oblasti lékařských věd',
#         '72.19.2 Výzkum a vývoj v\xa0oblasti technických věd',
#         '72.19.9 Výzkum a vývoj v\xa0oblasti jiných přírodních věd',
#         '72.19 Ostatní výzkum a vývoj v\xa0oblasti přírodních a\xa0technických věd',
#         '72.2 Výzkum a vývoj v\xa0oblasti společenských a\xa0humanitních věd',
#         '72.20 Výzkum a vývoj v\xa0oblasti společenských a\xa0humanitních věd',
#         '73.1 Reklamní činnosti', '73.11 Činnosti reklamních agentur',
#         '73.12 Zastupování médií při prodeji reklamního času a\xa0prostoru',
#         '73.2 Průzkum trhu a veřejného mínění',
#         '73.20 Průzkum trhu a veřejného mínění',
#         '74.1 Specializované návrhářské činnosti',
#         '74.10 Specializované návrhářské činnosti',
#         '74.2 Fotografické činnosti', '74.20 Fotografické činnosti',
#         '74.3 Překladatelské a tlumočnické činnosti',
#         '74.30 Překladatelské a tlumočnické činnosti',
#         '74.9 Ostatní profesní, vědecké a technické činnosti j. n.',
#         '74.90.1 Poradenství v\xa0oblasti bezpečnosti a ochrany zdraví při práci',
#         '74.90.2 Poradenství v\xa0oblasti požární ochrany',
#         '74.90.9 Jiné profesní, vědecké a technické činnosti j. n.',
#         '74.90 Ostatní profesní, vědecké a technické činnosti j. n.',
#         '75.0 Veterinární činnosti', '75.00 Veterinární činnosti'],
#        dtype=object),
#  'SEKCE N - ADMINISTRATIVNÍ A PODPŮRNÉ ČINNOSTI': array(['77.1 Pronájem a leasing motorových vozidel, kromě motocyklů',
#         '77.11 Pronájem a leasing\xa0automobilů a jiných lehkých motorových vozidel, kromě motocyklů',
#         '77.12 Pronájem a leasing nákladních automobilů',
#         '77.2 Pronájem a leasing výrobků pro osobní potřebu a\xa0převážně pro\xa0domácnost',
#         '77.21 Pronájem a leasing rekreačních a sportovních potřeb',
#         '77.22 Pronájem videokazet a disků',
#         '77.29 Pronájem a leasing ostatních výrobků pro osobní potřebu a převážně pro\xa0domácnost',
#         '77.3 Pronájem a leasing ostatních strojů, zařízení a\xa0výrobků',
#         '77.31 Pronájem a leasing zemědělských strojů a zařízení',
#         '77.32 Pronájem a leasing stavebních strojů a\xa0zařízení',
#         '77.33 Pronájem a leasing kancelářských strojů a zařízení, včetně\xa0počítačů',
#         '77.34 Pronájem a leasing vodních dopravních prostředků',
#         '77.35 Pronájem a leasing leteckých dopravních prostředků',
#         '77.39 Pronájem a leasing ostatních strojů, zařízení a výrobků j. n.',
#         '77.4 Leasing duševního vlastnictví a podobných produktů, kromě děl chráněných autorským právem',
#         '77.40 Leasing duševního vlastnictví a podobných produktů, kromě děl chráněných autorským právem',
#         '78.1 Činnosti agentur zprostředkujících zaměstnání',
#         '78.10 Činnosti agentur zprostředkujících zaměstnání',
#         '78.2 Činnosti agentur zprostředkujících práci na přechodnou dobu',
#         '78.20 Činnosti agentur zprostředkujících práci na přechodnou dobu',
#         '78.3 Ostatní poskytování lidských zdrojů',
#         '78.30 Ostatní poskytování lidských zdrojů',
#         '79.1 Činnosti cestovních agentur a cestovních kanceláří',
#         '79.11 Činnosti cestovních agentur',
#         '79.12 Činnosti cestovních kanceláří',
#         '79.9 Ostatní rezervační a související činnosti',
#         '79.90.1 Průvodcovské činnosti',
#         '79.90.9 Ostatní rezervační a související činnosti j. n.',
#         '79.90 Ostatní rezervační a související činnosti',
#         '80.1 Činnosti soukromých bezpečnostních agentur',
#         '80.10 Činnosti soukromých bezpečnostních agentur',
#         '80.2 Činnosti související s\xa0provozem bezpečnostních systémů',
#         '80.20 Činnosti související s\xa0provozem bezpečnostních systémů',
#         '80.3 Pátrací činnosti', '80.30 Pátrací činnosti',
#         '81.1 Kombinované pomocné činnosti',
#         '81.10 Kombinované pomocné činnosti', '81.2 Úklidové činnosti',
#         '81.21 Všeobecný úklid budov',
#         '81.22 Specializované čištění a úklid budov a průmyslových zařízení',
#         '81.29 Ostatní úklidové činnosti',
#         '81.3 Činnosti související s\xa0úpravou krajiny',
#         '81.30 Činnosti související s\xa0úpravou krajiny',
#         '82.1 Administrativní a kancelářské činnosti',
#         '82.11 Univerzální administrativní činnosti',
#         '82.19 Kopírování, příprava dokumentů a ostatní specializované kancelářské podpůrné činnosti',
#         '82.2 Činnosti zprostředkovatelských středisek po\xa0telefonu',
#         '82.20 Činnosti zprostředkovatelských středisek po telefonu',
#         '82.3 Pořádání konferencí a hospodářských výstav',
#         '82.30 Pořádání konferencí a hospodářských výstav',
#         '82.9 Podpůrné činnosti pro podnikání j. n.',
#         '82.91 Inkasní činnosti, ověřování solventnosti zákazníka',
#         '82.92 Balicí činnosti',
#         '82.99 Ostatní podpůrné činnosti pro podnikání j. n.'],
#        dtype=object),
#  'SEKCE O - VEŘEJNÁ SPRÁVA A OBRANA; POVINNÉ SOCIÁLNÍ ZABEZPEČENÍ': array(['84.1 Veřejná správa a hospodářská a sociální politika',
#         '84.11 Všeobecné činnosti veřejné správy',
#         '84.12 Regulace činností souvisejících s poskytováním zdravotní péče, vzděláváním, kulturou a sociální péčí, kromě sociálního zabezpečení',
#         '84.13 Regulace a podpora podnikatelského prostředí',
#         '84.2 Činnosti pro společnost jako celek',
#         '84.21.1 Pomoc cizím zemím při katastrofách nebo v\xa0nouzových situacích přímo nebo prostřednictvím mezinárodních organizací',
#         '84.21.2 Rozvíjení vzájemného přátelství a porozumění mezi národy',
#         '84.21.9 Ostatní činnosti v\xa0oblasti zahraničních věcí',
#         '84.21 Činnosti v\xa0oblasti zahraničních věcí',
#         '84.22 Činnosti v\xa0oblasti obrany',
#         '84.23 Činnosti v\xa0oblasti spravedlnosti a soudnictví',
#         '84.24 Činnosti v\xa0oblasti veřejného pořádku a bezpečnosti',
#         '84.25 Činnosti v\xa0oblasti protipožární ochrany',
#         '84.3 Činnosti v\xa0oblasti povinného sociálního zabezpečení',
#         '84.30 Činnosti v\xa0oblasti povinného sociálního zabezpečení'],
#        dtype=object),
#  'SEKCE P – VZDĚLÁVÁNÍ': array(['85.1 Předškolní vzdělávání', '85.10 Předškolní vzdělávání',
#         '85.2 Primární vzdělávání', '85.20 Primární vzdělávání',
#         '85.3 Sekundární vzdělávání',
#         '85.31.1 Základní vzdělávání na druhém stupni základních škol',
#         '85.31.2 Střední všeobecné vzdělávání',
#         '85.31 Sekundární všeobecné vzdělávání',
#         '85.32.1 Střední odborné vzdělávání na učilištích',
#         '85.32.2 Střední odborné vzdělávání na středních odborných školách',
#         '85.32 Sekundární odborné vzdělávání',
#         '85.4 Postsekundární vzdělávání',
#         '85.41 Postsekundární nikoli terciární vzdělávání',
#         '85.42 Terciární vzdělávání', '85.5 Ostatní vzdělávání',
#         '85.51 Sportovní a rekreační vzdělávání',
#         '85.52 Umělecké vzdělávání', '85.53.1 Činnosti autoškol',
#         '85.53.2 Činnosti leteckých škol',
#         '85.53.9 Činnosti ostatních škol řízení',
#         '85.53 Činnosti autoškol a jiných škol řízení',
#         '85.59.1 Vzdělávání v jazykových školách',
#         '85.59.2 Environmentální vzdělávání',
#         '85.59.3 Inovační vzdělávání', '85.59.9 Jiné vzdělávání j. n.',
#         '85.59 Ostatní vzdělávání j. n.',
#         '85.6 Podpůrné činnosti ve vzdělávání',
#         '85.60 Podpůrné činnosti ve vzdělávání'], dtype=object),
#  'SEKCE Q - ZDRAVOTNÍ A SOCIÁLNÍ PÉČE': array(['86.1 Ústavní zdravotní péče', '86.10 Ústavní zdravotní péče',
#         '86.2 Ambulantní a zubní zdravotní péče',
#         '86.21 Všeobecná ambulantní zdravotní péče',
#         '86.22 Specializovaná ambulantní zdravotní péče',
#         '86.23 Zubní péče',
#         '86.9 Ostatní činnosti související se zdravotní péčí',
#         '86.90.1 Činnosti související s ochranou veřejného zdraví',
#         '86.90.9 Ostatní činnosti související se zdravotní péčí j. n.',
#         '86.90 Ostatní činnosti související se zdravotní péčí',
#         '87.1 Sociální péče ve zdravotnických zařízeních ústavní péče',
#         '87.10 Sociální péče ve zdravotnických zařízeních ústavní péče',
#         '87.2 Sociální péče v zařízeních pro osoby s chronickým duševním onemocněním a osoby závislé na návykových látkách',
#         '87.20.1 Sociální péče v zařízeních pro osoby s chronickým duševním onemocněním',
#         '87.20.2 Sociální péče v zařízeních pro osoby závislé na návykových látkách',
#         '87.20 Sociální péče v zařízeních pro osoby s chronickým duševním onemocněním a osoby závislé na návykových látkách',
#         '87.3 Sociální péče v domovech pro seniory a osoby se zdravotním postižením',
#         '87.30.1 Sociální péče v domovech pro seniory',
#         '87.30.2 Sociální péče v domovech pro osoby se zdravotním postižením',
#         '87.30 Sociální péče v domovech pro seniory a osoby se zdravotním postižením',
#         '87.9 Ostatní pobytové služby sociální péče',
#         '87.90 Ostatní pobytové služby sociální péče',
#         '88.1 Ambulantní nebo terénní sociální služby pro seniory a osoby se zdravotním postižením',
#         '88.10.1 Ambulantní nebo terénní sociální služby pro seniory',
#         '88.10.2 Ambulantní nebo terénní sociální služby pro osoby se zdravotním postižením',
#         '88.10 Ambulantní nebo terénní sociální služby pro seniory a osoby se zdravotním postižením',
#         '88.9 Ostatní ambulantní nebo terénní sociální služby',
#         '88.91 Sociální služby poskytované dětem',
#         '88.99.1 Sociální služby pro uprchlíky, oběti katastrof',
#         '88.99.2 Sociální prevence', '88.99.3 Sociální rehabilitace',
#         '88.99.9 Jiné ambulantní nebo terénní sociální služby j. n.',
#         '88.99 Ostatní ambulantní nebo terénní sociální služby j. n.'],
#        dtype=object),
#  'SEKCE R - KULTURNÍ, ZÁBAVNÍ A\xa0REKREAČNÍ ČINNOSTI': array(['90.0 Tvůrčí, umělecké a zábavní činnosti', '90.01 Scénická umění',
#         '90.02 Podpůrné činnosti pro scénická umění',
#         '90.03 Umělecká tvorba', '90.04 Provozování kulturních zařízení',
#         '91.0 Činnosti knihoven, archivů, muzeí a jiných kulturních zařízení',
#         '91.01 Činnosti knihoven a archivů', '91.02 Činnosti muzeí',
#         '91.03 Provozování kulturních památek, historických staveb a\xa0obdobných turistických zajímavostí',
#         '91.04.1 Činnosti botanických a zoologických zahrad',
#         '91.04.2 Činnosti přírodních rezervací a národních parků',
#         '91.04 Činnosti botanických a zoologických zahrad, přírodních rezervací a\xa0národních parků',
#         '92.0 Činnosti heren, kasin a sázkových kanceláří',
#         '92.00 Činnosti heren, kasin a sázkových kanceláří',
#         '93.1 Sportovní činnosti',
#         '93.11 Provozování sportovních zařízení',
#         '93.12 Činnosti sportovních klubů', '93.13 Činnosti fitcenter',
#         '93.19 Ostatní sportovní činnosti',
#         '93.2 Ostatní zábavní a rekreační činnosti',
#         '93.21 Činnosti lunaparků a zábavních parků',
#         '93.29 Ostatní zábavní a rekreační činnosti j. n.'], dtype=object),
#  'SEKCE S - OSTATNÍ ČINNOSTI': array(['94.1 Činnosti podnikatelských, zaměstnavatelských a\xa0profesních organizací',
#         '94.11 Činnosti podnikatelských a zaměstnavatelských organizací',
#         '94.12 Činnosti profesních organizací',
#         '94.2 Činnosti odborových svazů',
#         '94.20 Činnosti odborových svazů',
#         '94.9 Činnosti ostatních organizací sdružujících osoby za účelem prosazování společných zájmů',
#         '94.91 Činnosti náboženských organizací',
#         '94.92 Činnosti politických stran a organizací',
#         '94.99.1 Činnosti organizací dětí a mládeže',
#         '94.99.2 Činnosti organizací na podporu kulturní činnosti',
#         '94.99.3 Činnosti organizací na podporu rekreační a\xa0zájmové činnosti',
#         '94.99.4 Činnosti spotřebitelských organizací',
#         '94.99.5 Činnosti environmentálních a ekologických hnutí',
#         '94.99.6 Činnosti organizací na ochranu a zlepšení postavení etnických, menšinových a jiných speciálních skupin',
#         '94.99.7 Činnosti občanských iniciativ, protestních hnutí',
#         '94.99.9 Činnosti ostatních organizací j. n.',
#         '94.99 Činnosti ostatních organizací sdružujících osoby za účelem prosazování společných zájmů j. n.',
#         '95.1 Opravy počítačů a komunikačních zařízení',
#         '95.11 Opravy počítačů a periferních zařízení',
#         '95.12 Opravy komunikačních zařízení',
#         '95.2 Opravy výrobků pro osobní potřebu a převážně pro\xa0domácnost',
#         '95.21 Opravy spotřební elektroniky',
#         '95.22 Opravy přístrojů a zařízení převážně pro domácnost, dům a\xa0zahradu',
#         '95.23 Opravy\xa0obuvi a kožených výrobků',
#         '95.24 Opravy nábytku a bytového zařízení',
#         '95.25 Opravy hodin, hodinek a klenotnických výrobků',
#         '95.29 Opravy ostatních výrobků pro osobní potřebu a převážně pro\xa0domácnost',
#         '96.0 Poskytování ostatních osobních služeb',
#         '96.01 Praní a chemické čištění textilních a kožešinových výrobků',
#         '96.02 Kadeřnické, kosmetické a podobné činnosti',
#         '96.03 Pohřební a související činnosti',
#         '96.04 Činnosti pro osobní a fyzickou pohodu',
#         '96.09 Poskytování ostatních osobních služeb j. n.'], dtype=object),
#  'SEKCE T - ČINNOSTI DOMÁCNOSTÍ JAKO\xa0ZAMĚSTNAVATELŮ; ČINNOSTI DOMÁCNOSTÍ PRODUKUJÍCÍCH BLÍŽE NEURČENÉ VÝROBKY A SLUŽBY PRO\xa0VLASTNÍ POTŘEBU': array(['97.0 Činnosti domácností jako zaměstnavatelů domácího personálu',
#         '97.00 Činnosti domácností jako zaměstnavatelů domácího personálu',
#         '98.1 Činnosti domácností produkujících blíže neurčené výrobky pro vlastní potřebu',
#         '98.10 Činnosti domácností produkujících blíže neurčené výrobky pro vlastní potřebu',
#         '98.2 Činnosti domácností poskytujících blíže neurčené služby pro vlastní potřebu',
#         '98.20 Činnosti domácností poskytujících blíže neurčené služby pro vlastní potřebu'],
#        dtype=object),
#  'SEKCE U - ČINNOSTI EXTERITORIÁLNÍCH ORGANIZACÍ A\xa0ORGÁNŮ': array(['99.0 Činnosti exteritoriálních organizací a orgánů',
#         '99.00 Činnosti exteritoriálních organizací a orgánů'],
#        dtype=object)}

# %%
df[df['skupina'] == '01.4'].sort_values(by='trida')
# Out:
#    sekce oddil skupina    trida                               nazev skupina1  \
# 22     A    01    01.4                             Živočišná výroba     01.4
# 23     A    01    01.4    01.41                 Chov mléčného skotu    01.41
# 24     A    01    01.4    01.42                   Chov jiného skotu    01.42
# 25     A    01    01.4    01.43       Chov koní a jiných koňovitých    01.43
# 26     A    01    01.4    01.44    Chov velbloudů a velbloudovitých    01.44
# 27     A    01    01.4    01.45                     Chov ovcí a koz    01.45
# 28     A    01    01.4    01.46                         Chov prasat    01.46
# 29     A    01    01.4    01.47                        Chov drůbeže    01.47
# 34     A    01    01.4    01.49               Chov ostatních zvířat    01.49
# 30     A    01    01.4  01.49.1  Chov drobných hospodářských zvířat  01.49.1
# 31     A    01    01.4  01.49.2            Chov kožešinových zvířat  01.49.2
# 32     A    01    01.4  01.49.3        Chov zvířat pro zájmový chov  01.49.3
# 33     A    01    01.4  01.49.9         Chov ostatních zvířat j. n.  01.49.9
#
#                                         nazev1
# 22                       01.4 Živočišná výroba
# 23                   01.41 Chov mléčného skotu
# 24                     01.42 Chov jiného skotu
# 25         01.43 Chov koní a jiných koňovitých
# 26      01.44 Chov velbloudů a velbloudovitých
# 27                       01.45 Chov ovcí a koz
# 28                           01.46 Chov prasat
# 29                          01.47 Chov drůbeže
# 34                 01.49 Chov ostatních zvířat
# 30  01.49.1 Chov drobných hospodářských zvířat
# 31            01.49.2 Chov kožešinových zvířat
# 32        01.49.3 Chov zvířat pro zájmový chov
# 33         01.49.9 Chov ostatních zvířat j. n.

# %%
for key in naces_dict.keys():
    print(key)
# Out:
# SEKCE A - ZEMĚDĚLSTVÍ, LESNICTVÍ A RYBÁŘSTVÍ
# SEKCE B - TĚŽBA A DOBÝVÁNÍ
# SEKCE C - ZPRACOVATELSKÝ PRŮMYSL
# SEKCE D – VÝROBA A ROZVOD ELEKTŘINY, PLYNU, TEPLA A KLIMATIZOVANÉHO VZDUCHU
# SEKCE E – ZÁSOBOVÁNÍ VODOU; ČINNOSTI SOUVISEJÍCÍ S ODPADNÍMI VODAMI, ODPADY A SANACEMI
# SEKCE F - STAVEBNICTVÍ
# SEKCE G - VELKOOBCHOD A MALOOBCHOD; OPRAVY A ÚDRŽBA MOTOROVÝCH VOZIDEL
# SEKCE H - DOPRAVA A SKLADOVÁNÍ
# SEKCE I - UBYTOVÁNÍ, STRAVOVÁNÍ A POHOSTINSTVÍ
# SEKCE J - INFORMAČNÍ A KOMUNIKAČNÍ ČINNOSTI
# SEKCE K - PENĚŽNICTVÍ A POJIŠŤOVNICTVÍ
# SEKCE L - ČINNOSTI V OBLASTI NEMOVITOSTÍ
# SEKCE M - PROFESNÍ, VĚDECKÉ A TECHNICKÉ ČINNOSTI
# SEKCE N - ADMINISTRATIVNÍ A PODPŮRNÉ ČINNOSTI
# SEKCE O - VEŘEJNÁ SPRÁVA A OBRANA; POVINNÉ SOCIÁLNÍ ZABEZPEČENÍ
# SEKCE P – VZDĚLÁVÁNÍ
# SEKCE Q - ZDRAVOTNÍ A SOCIÁLNÍ PÉČE
# SEKCE R - KULTURNÍ, ZÁBAVNÍ A REKREAČNÍ ČINNOSTI
# SEKCE S - OSTATNÍ ČINNOSTI
# SEKCE T - ČINNOSTI DOMÁCNOSTÍ JAKO ZAMĚSTNAVATELŮ; ČINNOSTI DOMÁCNOSTÍ PRODUKUJÍCÍCH BLÍŽE NEURČENÉ VÝROBKY A SLUŽBY PRO VLASTNÍ POTŘEBU
# SEKCE U - ČINNOSTI EXTERITORIÁLNÍCH ORGANIZACÍ A ORGÁNŮ
