# %%
import seaborn as sns
import pandas as pd
from _Grafy import getBarChart

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_2',
#  '_3',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'df',
#  'exit',
#  'getBarChart',
#  'get_ipython',
#  'open',
#  'pd',
#  'quit',
#  'sns']

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_who_class = pd.crosstab(df.pclass, df.who)
df_who_class
# Out:
# who     child  man  woman
# pclass
# 1           6  119     91
# 2          19   99     66
# 3          58  319    114

# %%
df_who_class.plot(kind='barh', stacked=True)
# Out:
# <Axes: ylabel='pclass'>

# %%
getBarChart(df_who_class, kind='hs')

# %%
getBarChart(df_who_class, kind='hs', total=True)

# %%
getBarChart(df_who_class, kind='hs', reverse=True)

# %%
getBarChart(df_who_class, kind='hs', reverse=True, total=True)

# %%
getBarChart(df_who_class, kind='hs', normalize=True, reverse=True)

# %%
getBarChart(df_who_class, kind='hs', normalize=True, reverse=True, total=True)

# %%
df_who_class
# Out:
# who     child  man  woman
# pclass
# 1           6  119     91
# 2          19   99     66
# 3          58  319    114

# %%
df_who_class.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='pclass'>

# %%
getBarChart(df_who_class, kind='vs')

# %%
getBarChart(df_who_class, kind='vs', total=True)

# %%
getBarChart(df_who_class, kind='vs', reverse=True)

# %%
getBarChart(df_who_class, kind='vs', reverse=True, total=True)

# %%
getBarChart(df_who_class, kind='vs', normalize=True)

# %%
getBarChart(df_who_class, kind='vs', normalize=True, total=True)

# %%
getBarChart(df_who_class, kind='vs', normalize=True, reverse=True)

# %%
getBarChart(df_who_class, kind='vs', normalize=True, reverse=True, total=True)

# %% [markdown]
# # NE stacked

# %%
df_who_class.plot(kind='bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
getBarChart(df_who_class)

# %%
getBarChart(df_who_class, total=True)

# %%
getBarChart(df_who_class, reverse=True)

# %%
getBarChart(df_who_class, reverse=True, total=True)

# %%
getBarChart(df_who_class, normalize=True)

# %%
getBarChart(df_who_class, normalize=True, total=True)

# %%
getBarChart(df_who_class, normalize=True, reverse=True)

# %%
getBarChart(df_who_class, normalize=True, reverse=True, total=True)

# %%
df_who_class.plot(kind='barh')
# Out:
# <Axes: ylabel='pclass'>

# %%
getBarChart(df_who_class, kind='h')

# %%
getBarChart(df_who_class, kind='h', total=True)

# %%
getBarChart(df_who_class, kind='h', total='mean')

# %%
getBarChart(df_who_class, kind='h', reverse=True)

# %%
getBarChart(df_who_class, kind='h', reverse=True, total=True)

# %%
getBarChart(df_who_class, kind='h', reverse=True, total='mean')

# %%
getBarChart(df_who_class, kind='h', normalize=True)

# %%
getBarChart(df_who_class, kind='h', normalize=True, total=True)

# %%
getBarChart(df_who_class, kind='h', normalize=True, reverse=True)

# %%
getBarChart(df_who_class, kind='h', normalize=True, reverse=True, total=True)

# %% [markdown]
# # Mean total

# %%
getBarChart(df_who_class, total=True)

# %%
getBarChart(df_who_class, total='sum')

# %%
getBarChart(df_who_class, total='mean')

# %%
getBarChart(df_who_class, normalize=True, total='mean')

# %%
getBarChart(df_who_class, normalize=True, total='sum')

# %%
getBarChart(df_who_class, kind='vs', normalize=True, total=True)
