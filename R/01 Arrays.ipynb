# %% [markdown]
# # Arrays

# %%
import numpy as np

# %%
a = np.array([0, 1, 2, 2.5, 3, 4, 5])
a
# Out:
# array([0. , 1. , 2. , 2.5, 3. , 4. , 5. ])

# %%
np.size(a)
# Out:
# 7

# %%
np.mean(a)
# Out:
# np.float64(2.5)

# %%
np.sum(a)
# Out:
# np.float64(17.5)

# %%
np.std(a)
# Out:
# np.float64(1.5811388300841898)

# %%
# std rucne
np.sqrt(np.sum([(i - np.mean(a))**2 for i in a])/np.size(a))
# Out:
# np.float64(1.5811388300841898)
